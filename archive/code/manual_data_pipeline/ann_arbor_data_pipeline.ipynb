# %%
# Importing packages

import requests
import json
import time #will use this to pause execution for a few seconds

import numpy as np
import pandas as pd

# %%
# Extracting Google Key
from configparser import ConfigParser
config = ConfigParser()
config.read('config.ini')
# extract key from a separate ini file where the key is stored
API_KEY = config['google']['api_key']

# %%
endpoint_url_start = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
# new api request string for new type of API requests
endpoint_url_start_2 = "https://maps.googleapis.com/maps/api/place/details/json?place_id="

# %%
# common places will be searched in many small radius circles
places_common = ['bakery', 'cafe', 'restaurant', 'meal_delivery', 'meal_takeaway', 'bar', 'convenience store',\
                'gas_station', 'supermarket', 'department_store', "tourist_attraction", "lodging"]
# uncommon places will be searched using Galveston as a whole
places_uncommon = ['airport', 'amusement_park', 'aquarium', 'casino', 'hospital',\
                'stadium', 'university', 'primary_school',\
                'school', 'secondary_school', 'zoo', 'movie_theater', 'shopping mall', "bowling_alley"]
# Creating dataframes to be filled
# dataframe for common types of places
aa_common = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status',\
                                    'types', 'delivery',\
                                    'dine_in', 'takeout', 'price_level', 'rating', 'user_ratings_total',\
                                    'serves_breakfast', 'serves_brunch','serves_lunch', 'serves_dinner',\
                                    'serves_vegetarian_food', 'serves_beer', 'serves_wine'])
# dataframe for uncommon types of places
aa_uncommon = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status',\
                                    'types', 'delivery',\
                                    'dine_in', 'takeout', 'price_level', 'rating', 'user_ratings_total',\
                                    'serves_breakfast', 'serves_brunch','serves_lunch', 'serves_dinner',\
                                    'serves_vegetarian_food', 'serves_beer', 'serves_wine'])
# Basic parameters for Ann Arbor as a whole
central_cord = "42.27583,-83.72916"
central_radius = "6026"
# Basic parameters for Ann Arbor as a whole
# centers of small radius circles I drew (see map screenshot for visualization of the small circles)
# small circles are from a website called "Calc Maps"
central_cord_small = [
    '42.29183,-83.78533', "42.29262,-83.76311", "42.27619,-83.79102", "42.28483,-83.77217", "42.27743,-83.77544"
    "42.26433,-83.79250", "42.26813,-83.77474", "42.28393,-83.76212", "42.27742,-83.76180", "42.29528,-83.74858",
    "42.28693,-83.75346", "42.28225,-83.75356", "42.28668,-83.74568", "42.28236,-83.74665", "42.28594,-83.73908",
    "42.28216,-83.73989", "42.27809,-83.74424", "42.27719,-83.75150", "42.26933,-83.76450", "42.27131,-83.75431",
    "42.26213,-83.76767", "42.29101,-83.73816", "42.28549,-83.73173", "42.29786,-83.73619", "42.27261,-83.74438",
    "42.26602,-83.75018", "42.26397,-83.75857", "42.25996,-83.77666", "42.27868,-83.73334", "42.27404,-83.73620",
    "42.25554,-83.76850", "42.26404,-83.73859", "42.25740,-83.74855", "42.25350,-83.75897", "42.30520,-83.77322",
    "42.29295,-83.72629", "42.30828,-83.73641", "42.30209,-83.72027", "42.24375,-83.74880", "42.25585,-83.73173",
    "42.31724,-83.71867", "42.24357,-83.72240", "42.31596,-83.69756", "42.30322,-83.70329", "42.29770,-83.69019",
    "42.28771,-83.71124", "42.27862,-83.72350", "42.26568,-83.72530", "42.27217,-83.70706", "42.26409,-83.71338",
    "42.25407,-83.71374", "42.23999,-83.70190", "42.31097,-83.67866", "42.28064,-83.69264", "42.26554,-83.69190",
    "42.25288,-83.69343", "42.28672,-83.68026", "42.27306,-83.67951", "42.23533,-83.68890"
]
# radius of each small circles I drew (see map screenshot for visualization of the small circles)
central_radius_small = [
    "1115", "747.45", "986.50", "533.43", "741.28", "1097", "619.23", "421.37", "629.36", "779.98", "383.65",
    "384.39", "347.37", "365.95", "238.89", "394.38", "220.20", "428.04", "562.29", "355.07", "420.07",
    "439.57", "413.89", "361.46", "528.77", "461.63", "570.84", "533.13", "455.62", "734.74", "550.11",
    "622.89", "685.18", "803.62", "1077", "656.64", "1053", "1084", "1397", "738.70", "1225", "1202",
    "1154", "800.99", "1174", "1084", "939.34", "588.51", "719.39", "950.97", "1178", "743.55", "884.65",
    "1011", "923.34", "1227", "462.10", "1185", "1150"
]

# %%
# function to append result to the dataframe
# Takes care of null returned from API request
# see API nearby search documentation for inside "" content
def append_place(json_results, df):
    l = len(df)
    for i, val in enumerate(json_results['results']):
        df.loc[l + i] = [val.get('name', np.nan), 
                        val.get('place_id', np.nan),
                        val.get('vicinity', np.nan), 
                        val.get('geometry', np.nan).get('location', np.nan),
                        val.get('business_status', np.nan),
                        val.get('types', np.nan),
                        val.get('delivery', np.nan),
                        val.get('dine_in', np.nan),
                        val.get('takeout', np.nan),
                        val.get('price_level', np.nan),
                        val.get('rating', np.nan),
                        val.get('user_ratings_total', np.nan),
                        val.get('serves_breakfast', np.nan),
                        val.get('serves_brunch', np.nan),
                        val.get('serves_lunch',np.nan),
                        val.get('serves_dinner', np.nan),
                        val.get('serves_vegetarian_food', np.nan),
                        val.get('serves_beer', np.nan),
                        val.get('serves_wine', np.nan)]

# %%
def small_circle_scrape():
    # for each small circle
    # search for all detailed info we need
    # then add the results to the big dataframe
    for i in range(0, len(central_cord_small)):
        for _type in places_common:
            endpoint_url = endpoint_url_start + "&location=" + central_cord_small[i] + "&radius=" + \
            central_radius_small[i] + "&region=us&type=" + _type + "&key=" + API_KEY

            params = {}

            res = requests.get(endpoint_url, params = params)
            results =  json.loads(res.content)
            # use the function we wrote before to append place to the galv_common df
            append_place(results, aa_common)

            # set a sleep time so that we won't burn the API tool
            time.sleep(1)

            # Pulling results from other pages
            while "next_page_token" in results:
                params['pagetoken'] = results['next_page_token']
                res = requests.get(endpoint_url, params = params)
                results =  json.loads(res.content)
                append_place(results, aa_common)
                time.sleep(1)
    return aa_common

aa_common = small_circle_scrape()
# drop duplicates
aa_common.drop_duplicates(subset=['place_id'], inplace=True)
# recode the category for each place
aa_common['category'] = aa_common['types'].apply(lambda x: x[0])

# %%
def large_circle_scrape():
    # code doing the actual scraping of API
    aa_uncommon_full = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status',\
                                        'types', 'delivery',\
                                        'dine_in', 'takeout', 'price_level', 'rating', 'user_ratings_total',\
                                        'serves_breakfast', 'serves_brunch','serves_lunch', 'serves_dinner',\
                                        'serves_vegetarian_food', 'serves_beer', 'serves_wine'])
    for i in range(5):
        for _type in places_uncommon:
            endpoint_url = endpoint_url_start + "&location=" + central_cord + "&radius=" + \
            central_radius + "&region=us&type=" + _type + "&key=" + API_KEY
            
            params = {}
            
            res = requests.get(endpoint_url, params = params)
            results =  json.loads(res.content)
            append_place(results, aa_uncommon)
            
            time.sleep(1)
            
            # Pulling results from other pages since Googel only display 20 results per page
            while "next_page_token" in results:
                params['pagetoken'] = results['next_page_token']
                res = requests.get(endpoint_url, params = params)
                results =  json.loads(res.content)
                append_place(results, aa_uncommon)
                time.sleep(1)
        aa_uncommon_full = pd.concat([aa_uncommon_full, aa_uncommon])
    return aa_uncommon_full

aa_uncommon_full = large_circle_scrape()
# weirdly google API does not return the same number of results for each type of place
# so we run the code for 5 times to get a more complete list
# then we drop the duplicates
aa_uncommon_full.drop_duplicates(subset=['place_id'], inplace=True)
# recode the category of each place
aa_uncommon_full['category'] = aa_uncommon_full['types'].apply(lambda x: x[0])

# %%
#remove_rows_from_other_cities:
# since the radius also includes cities outside of Ann Arbor, we need to filter for Ann Arbor locations only
# for the dataframe of uncommon types of locations
# first reset the index
aa_uncommon_full.reset_index(drop=True, inplace=True)
for i in range(0, len(aa_uncommon_full)):
    string = aa_uncommon_full['Address'][i]
    if "Ann Arbor" not in string:
        aa_uncommon_full.drop(labels=i, axis=0, inplace=True)

# since the radius also includes cities outside of Ann Arbor, we need to filter for Ann Arbor locations only
# for the dataframe of common types of locations
# first reset the index
aa_common.reset_index(drop=True, inplace=True)
for i in range(0, len(aa_common)):
    string = aa_common['Address'][i]
    if "Ann Arbor" not in string:
        aa_common.drop(labels=i, axis=0, inplace=True)

# %%
# Creating a list of unique place ids that we can use in Google Places Details API search to get business hours
aa_common_ids = np.unique(aa_common['place_id'])
aa_uncommon_ids = np.unique(aa_uncommon_full['place_id'])
# creating dataset to fill with business hours
aa_common_hours = pd.DataFrame(columns=['Name','place_id','business_hours', 'business_hours_text'])
aa_uncommon_hours = pd.DataFrame(columns=['Name','place_id','business_hours','business_hours_text'])

# %%
def append_place_2(json_results, df):
    l = len(df)
    val = json_results['result']
    if len(val) == 2:
        df.loc[l + 1] = [val.get('name', np.nan), 
                         val.get('place_id', np.nan),
                         np.nan,
                         np.nan]
    else:
        df.loc[l + 1] = [val.get('name', np.nan), 
                         val.get('place_id', np.nan),
                         val.get('opening_hours', np.nan).get('periods', np.nan),
                         val.get('opening_hours', np.nan).get('weekday_text', np.nan)]

# %%
def small_circle_detail_scrape():
    # creating a business hours dataset for the common places
    for place_id in aa_common_ids:
        endpoint_url = endpoint_url_start_2 + place_id + \
        "&fields=name%2Cplace_id%2Copening_hours&key=" + API_KEY
        
        params = {}
        
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        append_place_2(results, aa_common_hours)
        
        time.sleep(1)
    return aa_common_hours

aa_common_hours = small_circle_detail_scrape()

# %%
def large_circle_detail_scrape():
    # creating a business hours dataset for the uncommon places
    for place_id in aa_uncommon_ids:
        endpoint_url = endpoint_url_start_2 + place_id + \
        "&fields=name%2Cplace_id%2Copening_hours&key=" + API_KEY
        
        params = {}
        
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        append_place_2(results, aa_uncommon_hours)
        
        time.sleep(1)
    return aa_uncommon_hours

aa_uncommon_hours = large_circle_detail_scrape()

# %%
# merge distribution search and detial search
def merge_dist_detail(aa_common, aa_uncommon_full, aa_common_hours, aa_uncommon_hours):
    # merging previous datasets with business hours datasets
    aa_common = aa_common.merge(aa_common_hours, how='left', left_on=['Name', 'place_id'], right_on=['Name', 'place_id'])
    aa_uncommon_full = aa_uncommon_full.merge(aa_uncommon_hours, how='left', left_on=['Name', 'place_id'], right_on=['Name', 'place_id'])
    return aa_common, aa_uncommon_full

aa_common, aa_uncommon = merge_dist_detail(aa_common, aa_uncommon_full, aa_common_hours, aa_uncommon_hours)

# %%
# The initial string for the api
endpoint_url_start = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

# Specifying the types of places in a list
# common places will be searched in many small radius circles
clct_common = ['bus_station', 'light_rail_station', 'parking', \
              'taxi_stand', 'train_station', 'transit_station']
# uncommon places will be searched using Galveston as a whole
clct_uncommon = ['art_gallery', 'campground', 'car_rental', 'museum', 'night_club',\
                'spa', 'travel_agency']

# Creating dataframes to be filled
# dataframe for common types of places
aa_clct_common = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status','types'])
# dataframe for uncommon types of places
aa_clct_uncommon = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status','types'])

# %%
def append_clct_place(json_results, df):
    l = len(df)
    for i, val in enumerate(json_results['results']):
        df.loc[l + i] = [val.get('name', np.nan), 
                         val.get('place_id', np.nan),
                         val.get('vicinity', np.nan), 
                         val.get('geometry', np.nan).get('location', np.nan),
                         val.get('business_status', np.nan),
                         val.get('types', np.nan)]

# %%
def residential_large_circle_scrape():
    # code doing the actual scraping of API
    aa_clct_uncommon_full = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status','types'])
    # since there is randomization in the API, we will run the code 5 times to get a more complete dataset
    for i in range(5):
        for _type in clct_uncommon:
            endpoint_url = endpoint_url_start + "&location=" + central_cord + "&radius=" + \
            central_radius + "&region=us&type=" + _type + "&key=" + API_KEY
            
            params = {}
            
            res = requests.get(endpoint_url, params = params)
            results =  json.loads(res.content)
            append_clct_place(results, aa_clct_uncommon)
            
            
            time.sleep(1)
            
            # Pulling results from other pages since Googel only display 20 results per page
            while "next_page_token" in results:
                params['pagetoken'] = results['next_page_token']
                res = requests.get(endpoint_url, params = params)
                results =  json.loads(res.content)
                append_clct_place(results, aa_clct_uncommon)
                time.sleep(1)
        aa_clct_uncommon_full = pd.concat([aa_clct_uncommon_full, aa_clct_uncommon])
    return aa_clct_uncommon_full

aa_clct_uncommon_full = residential_large_circle_scrape()
# drop duplicates
aa_clct_uncommon_full.drop_duplicates(subset=['place_id'], inplace=True)
aa_clct_uncommon_full.reset_index(drop=True, inplace=True)
# recode category for each place
aa_clct_uncommon_full['category'] = aa_clct_uncommon_full['types'].apply(lambda x: x[0])

# %%
def residential_small_circle_scrape():
    # for each small circle
    # search for all detailed info we need
    # then add the results to the big dataframe
    for i in range(0, len(central_cord_small)):
        for _type in clct_common:
            endpoint_url = endpoint_url_start + "&location=" + central_cord_small[i] + "&radius=" + \
            central_radius_small[i] + "&region=us&type=" + _type + "&key=" + API_KEY

            params = {}

            res = requests.get(endpoint_url, params = params)
            results =  json.loads(res.content)
            # use the function we wrote before to append place to the galv_common df
            append_clct_place(results, aa_clct_common)


            time.sleep(1)

            # Pulling results from other pages
            while "next_page_token" in results:
                params['pagetoken'] = results['next_page_token']
                res = requests.get(endpoint_url, params = params)
                results =  json.loads(res.content)
                append_clct_place(results, aa_clct_common)
                time.sleep(1)
    return aa_clct_common

aa_clct_common = residential_small_circle_scrape()
aa_clct_common.drop_duplicates(subset=['place_id'], inplace=True)
aa_clct_common.reset_index(drop=True, inplace=True)
# recode category for each place
aa_clct_common['category'] = aa_clct_common['types'].apply(lambda x: x[0])

# %%
# since the radius also includes cities outside Ann Arbor, we need to filter for Ann Arbor locations only
# for the dataframe of uncommon types of locations
for i in range(0, len(aa_clct_uncommon_full)):
    string = aa_clct_uncommon_full['Address'][i]
    if "Ann Arbor" not in string:
        aa_clct_uncommon_full.drop(labels=i, axis=0, inplace=True)

# for the dataframe of common types of locations
for i in range(0, len(aa_clct_common)):
    string = aa_clct_common['Address'][i]
    if "Ann Arbor" not in string:
        aa_clct_common.drop(labels=i, axis=0, inplace=True)

# %%
# Below is keyword search for residential areas
# residential places types
clct_residential = ['apartment', 'condominium', 'townhouse']
# dataframe for residential places
aa_resid = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status','types'])

# %%
def residential_scrape():
    # code doing the actual scraping of API
    aa_resid_full = pd.DataFrame(columns=['Name','place_id', 'Address','Coordinates', 'business_status','types'])
    for i in range(5):
        for _keyword in clct_residential:
            endpoint_url = endpoint_url_start + "&location=" + central_cord + "&radius=" + \
            central_radius + '&keyword=' + _keyword + "&key=" + API_KEY
            
            params = {}
            
            res = requests.get(endpoint_url, params = params)
            results =  json.loads(res.content)
            append_clct_place(results, aa_resid)
            
            
            time.sleep(2)
            
            # Pulling results from other pages since Googel only display 20 results per page
            while "next_page_token" in results:
                params['pagetoken'] = results['next_page_token']
                res = requests.get(endpoint_url, params = params)
                results =  json.loads(res.content)
                append_clct_place(results, aa_resid)
                time.sleep(2)
        aa_resid_full = pd.concat([aa_resid_full, aa_resid])
    return aa_resid_full

aa_resid_full = residential_scrape()
aa_resid_full.drop_duplicates(subset=['place_id'], inplace=True)
aa_resid_full.reset_index(drop=True, inplace=True)
aa_resid_full['category'] = aa_resid_full['types'].apply(lambda x: x[0])

# %%
# since the radius also includes cities outside of Ann Arbor, we need to filter for Ann Arbor locations only
# for the dataframe of uncommon types of locations
for i in range(0, len(aa_resid_full)):
    string = aa_resid_full['Address'][i]
    if "Ann Arbor" not in string:
        aa_resid_full.drop(labels=i, axis=0, inplace=True)

# %%
aa_common.to_csv('aa_common.csv')
aa_uncommon.to_csv('aa_uncommon.csv')
aa_clct_common.to_csv('aa_clct_common.csv')
aa_clct_uncommon.to_csv('aa_clct_uncommon.csv')
aa_resid.to_csv('aa_resid.csv')

# %%
# Extracting Yelp Key
from configparser import ConfigParser
config = ConfigParser()
config.read('config.ini')

API_KEY = "Bearer "  + config['yelp']['api_key']

# %%
# The url accessing to the Yelp Business Details API
endpoint_url_start = "https://api.yelp.com/v3/businesses/search?"

# Initial the dataframe to store business details info
aa_locations = pd.DataFrame(columns=['Name','Address','Coordinates',"id"])

# %%
# Get the number of businesses in Ann Arbor
res = requests.get(url=endpoint_url_start,
                        params = {"location":"Ann Arbor, MI"},
                        headers={"Authorization":API_KEY}
                        )
response = json.loads(res.content)
total_aa = response["total"]

# %%
print("There are " + str(total_aa) + " businesses in Ann Arbor")
# Out:
# There are 1100 businesses in Ann Arbor

# %%
print(response)
# Out:
# {'businesses': [{'id': 'uTMqhmpgfpDMLN3W3YvMeQ', 'alias': 'frita-batidos-ann-arbor', 'name': 'Frita Batidos', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL52xtE-3WvhGr74Irw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/frita-batidos-ann-arbor?adjust_creative=kl8jOau67NZclbVQDYPhNQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kl8jOau67NZclbVQDYPhNQ', 'review_count': 2145, 'categories': [{'alias': 'cuban', 'title': 'Cuban'}, {'alias': 'burgers', 'title': 'Burgers'}], 'rating': 4.5, 'coordinates': {'latitude': 42.2803651, 'longitude': -83.7491532}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '117 W Washington St', 'address2': '', 'address3': '', 'city': 'Ann Arbor', 'zip_code': '48104', 'country': 'US', 'state': 'MI', 'display_address': ['117 W Washington St', 'Ann Arbor, MI 48104']}, 'phone': '+17347612882', 'display_phone': '(734) 761-2882', 'distance': 1243.5784044949269}, {'id': 'yNIYH9041m1JEyRS-N_LNw', 'alias': 'aventura-ann-arbor', 'name': 'Aventura', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZV__mfk-Yj-2FEokw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/aventura-ann-arbor?adjust_creative=kl8jOau67NZclbVQDYPhNQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kl8jOau67NZclbVQDYPhNQ', 'review_count': 857, 'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'alias': 'spanish', 'title': 'Spanish'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 42.280283, 'longitude': -83.746494}, 'transactions': ['delivery'], 'price': '$$$', 'location': {'address1': '216 E Washington St', 'address2': '', 'address3': '', 'city': 'Ann Arbor', 'zip_code': '48104', 'country': 'US', 'state': 'MI', 'display_address': ['216 E Washington St', 'Ann Arbor, MI 48104']}, 'phone': '+17343693153', 'display_phone': '(734) 369-3153', 'distance': 1064.463194980032}, {'id': 'Fv2VLzVj9ATLcTbFehTDjg', 'alias': 'savas-ann-arbor', 'name': "Sava's", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89q9xdE_FHCkUSOjHg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/savas-ann-arbor?adjust_creative=kl8jOau67NZclbVQDYPhNQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kl8jOau67NZclbVQDYPhNQ', 'review_count': 1281, 'categories': [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}], 'rating': 4.0, 'coordinates': {'latitude': 42.279605, 'longitude': -83.7409649}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '216 S State St', 'address2': '', 'address3': '', 'city': 'Ann Arbor', 'zip_code': '48104', 'country': 'US', 'state': 'MI', 'display_address': ['216 S State St', 'Ann Arbor, MI 48104']}, 'phone': '+17346232233', 'display_phone': '(734) 623-2233', 'distance': 773.1837220520521}, {'id': 'tZmiwMg9Hdc8PcsKSuWQOg', 'alias': 'blue-llama-jazz-club-ann-arbor', 'name': 'Blue LLama Jazz Club', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9GbWlOQP---CFkdSQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/blue-llama-jazz-club-ann-arbor?adjust_creative=kl8jOau67NZclbVQDYPhNQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kl8jOau67NZclbVQDYPhNQ', 'review_count': 103, 'categories': [{'alias': 'jazzandblues', 'title': 'Jazz & Blues'}, {'alias': 'musicvenues', 'title': 'Music Venues'}, {'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 4.5, 'coordinates': {'latitude': 42.279019, 'longitude': -83.749017}, 'transactions': ['delivery', 'pickup'], 'price': '$$$', 'location': {'address1': '314 S Main St', 'address2': None, 'address3': '', 'city': 'Ann Arbor', 'zip_code': '48104', 'country': 'US', 'state': 'MI', 'display_address': ['314 S Main St', 'Ann Arbor, MI 48104']}, 'phone': '+17343723200', 'display_phone': '(734) 372-3200', 'distance': 1129.2118290814615}, {'id': '4RE ...

# %%
# function to append the business detailed info to the dataframe
# Takes care of null returned from API request
def append_place(response, df):
    l = len(df)
    for i, val in enumerate(response["businesses"]):
        df.loc[l + i] = [val.get('name', np.nan), 
                         val.get('location', np.nan).get("display_address"), 
                         val.get('coordinates', np.nan),
                         val.get("id",np.nan)]

# %%
# Use the function I defined above, I extract the info from the Yelp API and store them into the dataframe I made.
# total_aa is the total number of businesses.
location = {"Ann Arbor, MI": [aa_locations, total_aa]}
# Go through Galveston and Hilo
for i,v in location.items():
    # Here, I got 20 business info each time until I got all business in a city. 
    # The reason is that one page of Yelp API contains 20 businesses so I cannot get more than 20 business details each time. 
    for t in range(0, 1000, 20):
        res = requests.get(url=endpoint_url_start,
                        params = {"location":i, "offset":t},
                        headers={"Authorization":API_KEY}
                        )
        response = json.loads(res.content)
        append_place(response, v[0])

# %%
# in case i mess up with something later, save a copy of the dataframe
aa_locations_copy = aa_locations.copy()
aa_locations_copy
# Out:
#                       Name                                           Address  \
# 0            Frita Batidos        [117 W Washington St, Ann Arbor, MI 48104]
# 1                   Sava's             [216 S State St, Ann Arbor, MI 48104]
# 2                 Aventura        [216 E Washington St, Ann Arbor, MI 48104]
# 3     Blue LLama Jazz Club              [314 S Main St, Ann Arbor, MI 48104]
# 4       Mani Osteria & Bar           [341 E Liberty St, Ann Arbor, MI 48104]
# ...                    ...                                               ...
# 2815                Arby's                  [195 Baker Rd, Dexter, MI 48130]
# 2816                Subway           [1010 E Michigan Ave, Saline, MI 48176]
# 2817      St. Joe's Market   [5301 McAuley Dr, Ypsilanti Township, MI 48197]
# 2818         Marco's Pizza       [6065 Rawsonville Rd, Belleville, MI 48111]
# 2819             Starbucks  [2010 Whittaker Rd, Kroger, Ypsilanti, MI 48197]
#
#                                             Coordinates  \
# 0     {'latitude': 42.2803651, 'longitude': -83.7491...
# 1     {'latitude': 42.279605, 'longitude': -83.7409649}
# 2      {'latitude': 42.280283, 'longitude': -83.746494}
# 3      {'latitude': 42.279019, 'longitude': -83.749017}
# 4     {'latitude': 42.2795793749763, 'longitude': -8...
# ...                                                 ...
# 2815  {'latitude': 42.29627548731949, 'longitude': -...
# 2816  {'latitude': 42.17350939912832, 'longitude': -...
# 2817  {'latitude': 42.2669029, 'longitude': -83.651123}
# 2818  {'latitude': 42.20276653223271, 'longitude': -...
# 2819  {'latitude': 42.21180481, 'longitude': -83.620...
#
#                           id
# 0     uTMqhmpgfpDMLN3W3YvMeQ
# 1     Fv2VLzVj9ATLcTbFehTDjg
# 2     yNIYH9041m1JEyRS-N_LNw
# 3     tZmiwMg9Hdc8PcsKSuWQOg
# 4     4REtzXpQYy8dVev8RjWbSQ
# ...                      ...
# 2815  kJmVHN-GMwVrteextgp_eA
# 2816  XX8t6iNKDZq9eWHxlnVakQ
# 2817  Q5ul2KsOCms343REVhMa9w
# 2818  7ooBlkHpLEDqlidn49QN5A
# 2819  r6dwHEqcEqavsTQ9DPpDkA
#
# [2820 rows x 4 columns]

# %%
# Originally, the address is not in string form. I use the following code to turn the address to string form
full_address_aa = []
for i in aa_locations["Address"]:
    full_address_aa.append(" ".join([j for j in i]))
aa_locations["Address"] = full_address_aa

#Extract Ann Arbor's latitude and longitude from the coordinate column as columns
aa_latitude = []
aa_longitude = []
for i in aa_locations["Coordinates"]:
    aa_latitude.append(i["latitude"])
    aa_longitude.append(i["longitude"])
aa_locations["latitude"] = aa_latitude
aa_locations["longitude"] = aa_longitude

# %%
""" # Use a list to store all json files of Galveston getting from Business details API
# for debug purpose, not using the data here
aa_json_list = []
endpoint_url = "https://api.yelp.com/v3/businesses/"
for i in aa_locations["id"]:
    endpoint_url_detail = endpoint_url + i
    res = requests.get(url=endpoint_url_detail,
                        headers={"Authorization":API_KEY}
                        )
    response = json.loads(res.content)
    aa_json_list.append(response)  """

# %%
# Use a Pandas Dataframe to store all json files of Ann Arbor getting from Business details API
from pandas import json_normalize
aa_df_list = []
endpoint_url = "https://api.yelp.com/v3/businesses/"
# Use ID as key to extract data
for i in aa_locations["id"]:
    endpoint_url_detail = endpoint_url + i
    res = requests.get(url=endpoint_url_detail,
                        headers={"Authorization":API_KEY}
                        )
    df = json_normalize(res.json())
    aa_df_list.append(df)
aa_details = pd.concat(aa_df_list)

# %%
# in case i mess up with something later, save a copy of the dataframe
aa_details_copy = aa_details.copy()
aa_details_copy.head()
# Out:
#                        id                           alias  \
# 0  uTMqhmpgfpDMLN3W3YvMeQ         frita-batidos-ann-arbor
# 0  yNIYH9041m1JEyRS-N_LNw              aventura-ann-arbor
# 0  Fv2VLzVj9ATLcTbFehTDjg                 savas-ann-arbor
# 0  tZmiwMg9Hdc8PcsKSuWQOg  blue-llama-jazz-club-ann-arbor
# 0  4REtzXpQYy8dVev8RjWbSQ  mani-osteria-and-bar-ann-arbor
#
#                    name                                          image_url  \
# 0         Frita Batidos  https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL5...
# 0              Aventura  https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZ...
# 0                Sava's  https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89...
# 0  Blue LLama Jazz Club  https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9...
# 0    Mani Osteria & Bar  https://s3-media3.fl.yelpcdn.com/bphoto/LJscB4...
#
#    is_claimed  is_closed                                                url  \
# 0        True      False  https://www.yelp.com/biz/frita-batidos-ann-arb...
# 0        True      False  https://www.yelp.com/biz/aventura-ann-arbor?ad...
# 0        True      False  https://www.yelp.com/biz/savas-ann-arbor?adjus...
# 0        True      False  https://www.yelp.com/biz/blue-llama-jazz-club-...
# 0        True      False  https://www.yelp.com/biz/mani-osteria-and-bar-...
#
#           phone   display_phone  review_count  ... location.zip_code  \
# 0  +17347612882  (734) 761-2882          2145  ...             48104
# 0  +17343693153  (734) 369-3153           857  ...             48104
# 0  +17346232233  (734) 623-2233          1281  ...             48104
# 0  +17343723200  (734) 372-3200           103  ...             48104
# 0  +17347696700  (734) 769-6700           956  ...             48104
#
#    location.country location.state  \
# 0                US             MI
# 0                US             MI
# 0                US             MI
# 0                US             MI
# 0                US             MI
#
#                      location.display_address location.cross_streets  \
# 0  [117 W Washington St, Ann Arbor, MI 48104]
# 0  [216 E Washington St, Ann Arbor, MI 48104]
# 0       [216 S State St, Ann Arbor, MI 48104]
# 0        [314 S Main St, Ann Arbor, MI 48104]
# 0     [341 E Liberty St, Ann Arbor, MI 48104]
#
#   coordinates.latitude coordinates.longitude special_hours messaging.url  \
# 0            42.280365            -83.749153           NaN           NaN
# 0            42.280283            -83.746494           NaN           NaN
# 0            42.279605            -83.740965           NaN           NaN
# 0            42.279019            -83.749017           NaN           NaN
# 0            42.279579            -83.744245           NaN           NaN
#
#   messaging.use_case_text
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
# 0                     NaN
#
# [5 rows x 30 columns]

# %%
# Define a function to help as detect NaN value
def isNaN(num):
    return num != num

# Get all rows that did not get accurate information due to "too many requests" error
# I need to replace these rows with error messages to rows with accurate business details information
aa_nan = []
for i in range(len(list(aa_details["name"]))):
    if isNaN(list(aa_details["name"])[i]):
        aa_nan.append(i)

# %%
# in case I mess up with something later, save a copy of the list
aa_nan_copy = aa_nan.copy()

# %%
aa_nan
# Out:
# []

# %%
""" # Get the accurate information of the rows with problems that I located above
# please note that you will not neccessarily get empty rows if you run the code again
# also the index of empty rows will be different each time
# so please check aa_nan first before running anything
endpoint_url = "https://api.yelp.com/v3/businesses/"
aa_nan_detail_holder = pd.DataFrame()
for num in aa_nan:
    id_num = aa_locations.iloc[num]["id"]
    endpoint_url_detail = endpoint_url + id_num
    res = requests.get(url=endpoint_url_detail,
                            headers={"Authorization":API_KEY}
                            )
    aa_nan_detail = json_normalize(res.json())
    aa_nan_detail_holder = pd.concat([aa_nan_detail_holder, aa_nan_detail])

    # Reset index and drop the blank line
    # aa_details = aa_details.reset_index()
    aa_details = aa_details.drop(num)

# Merge the row with the accurate info I missed before to the original dataset
aa_details = aa_details.iloc[:,1:]
aa_details_final = pd.concat([aa_details, aa_nan_detail_holder])
aa_details_final = aa_details_final.reset_index()

# Clean unused column
aa_details_final = aa_details_final.iloc[:,1:] """
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/l5/yp473jqn5gq93py9ykz0gz140000gn/T/ipykernel_21571/2143306867.py in <module>
#      13     # Reset index and drop the blank line
#      14     # aa_details = aa_details.reset_index()
# ---> 15     aa_details = aa_details.drop(num)
#      16
#      17 # Merge the row with the accurate info I missed before to the original dataset
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4338                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4339                 if errors == "raise" and labels_missing:
# -> 4340                     raise KeyError(f"{labels} not found in axis")
#    4341
#    4342             if is_extension_array_dtype(mask.dtype):
#
# KeyError: '[2179] not found in axis'

# %%
# display max columns
pd.set_option('display.max_columns', None)
aa_details
# Out:
#                         id                                         alias  \
# 0   uTMqhmpgfpDMLN3W3YvMeQ                       frita-batidos-ann-arbor
# 0   yNIYH9041m1JEyRS-N_LNw                            aventura-ann-arbor
# 0   Fv2VLzVj9ATLcTbFehTDjg                               savas-ann-arbor
# 0   tZmiwMg9Hdc8PcsKSuWQOg                blue-llama-jazz-club-ann-arbor
# 0   4REtzXpQYy8dVev8RjWbSQ                mani-osteria-and-bar-ann-arbor
# ..                     ...                                           ...
# 0   4ZtSjxdv7lXd_RTCkAbawg  polo-fields-golf-and-country-clubs-ypsilanti
# 0   O7pfu3-HWLHuI8MNZFGOzg          glencoe-lakes-nature-trail-ann-arbor
# 0   4WD8MHDHpl_JFzbmduodyQ                  little-mac-shack-ann-arbor-2
# 0   PU93OtU8LnfW-lB-oBjSDg                        speedway-whitmore-lake
# 0   x61suUXHQFfyTl_fClHIaw                      burger-king-belleville-4
#
#                                 name  \
# 0                      Frita Batidos
# 0                           Aventura
# 0                             Sava's
# 0               Blue LLama Jazz Club
# 0                 Mani Osteria & Bar
# ..                               ...
# 0   Polo Fields Golf & Country Clubs
# 0         Glencoe Lakes Nature Trail
# 0                   Little Mac Shack
# 0                           Speedway
# 0                        Burger King
#
#                                             image_url  is_claimed  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL5...        True      False
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZ...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89...        True      False
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9...        True      False
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/LJscB4...        True      False
# ..                                                ...         ...        ...
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/dzsLMt...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu2...       False      False
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/QKtLUM...       False      False
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/slYlJ7...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/40ovUv...        True      False
#
#                                                   url         phone  \
# 0   https://www.yelp.com/biz/frita-batidos-ann-arb...  +17347612882
# 0   https://www.yelp.com/biz/aventura-ann-arbor?ad...  +17343693153
# 0   https://www.yelp.com/biz/savas-ann-arbor?adjus...  +17346232233
# 0   https://www.yelp.com/biz/blue-llama-jazz-club-...  +17343723200
# 0   https://www.yelp.com/biz/mani-osteria-and-bar-...  +17347696700
# ..                                                ...           ...
# 0   https://www.yelp.com/biz/polo-fields-golf-and-...  +17349981555
# 0   https://www.yelp.com/biz/glencoe-lakes-nature-...
# 0   https://www.yelp.com/biz/little-mac-shack-ann-...  +17349975399
# 0   https://www.yelp.com/biz/speedway-whitmore-lak...  +17344498990
# 0   https://www.yelp.com/biz/burger-king-bellevill...  +17344840710
#
#      display_phone  review_count  \
# 0   (734) 761-2882          2145
# 0   (734) 369-3153           857
# 0   (734) 623-2233          1281
# 0   (734) 372-3200           103
# 0   (734) 769-6700           956
# ..             ...           ...
# 0   (734) 998-1555             2
# 0                              1
# 0   (734) 997-5399             1
# 0   (734) 449-8990             2
# 0   (734) 484-0710            11
#
#                                            categories  rating  \
# 0   [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.5
# 0   [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...     4.0
# 0   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 0   [{'alias': 'jazzandblues', 'title': 'Jazz & Bl...     4.5
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# ..                                                ...     ...
# 0   [{'alias': 'golf', 'title': 'Golf'}, {'alias':...     4.0
# 0              [{'alias': 'parks', 'title': 'Parks'}]     3.0
# 0   [{'alias': 'fooddeliveryservices', 'title': 'F...     1.0
# 0   [{'alias': 'servicestations', 'title': 'Gas St...     3.5
# 0   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                                photos price  \
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL...    $$
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/YeASI...   $$$
# 0   [https://s3-media1.fl.yelpcdn.com/bphoto/FZHW8...    $$
# 0   [https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z...   $$$
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/LJscB...    $$
# ..                                                ...   ...
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/dzsLM...   NaN
# 0   [https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu...   NaN
# 0   [https://s3-media2.fl.yelpcdn.com/bphoto/QKtLU...   NaN
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/7mP8j...   NaN
# 0   [https://s3-media4.fl.yelpcdn.com/bphoto/GQpaD...     $
#
#                                                 hours        transactions  \
# 0   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# ..                                                ...                 ...
# 0   [{'open': [{'is_overnight': False, 'start': '0...                  []
# 0                                                 NaN                  []
# 0                                                 NaN          [delivery]
# 0   [{'open': [{'is_overnight': True, 'start': '00...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
#
#       location.address1 location.address2 location.address3  location.city  \
# 0   117 W Washington St                                          Ann Arbor
# 0   216 E Washington St                                          Ann Arbor
# 0        216 S State St                                          Ann Arbor
# 0         314 S Main St              None                        Ann Arbor
# 0      341 E Liberty St                                          Ann Arbor
# ..                  ...               ...               ...            ...
# 0       2955 Packard Rd                                          Ypsilanti
# 0    4741 Washtenaw Ave                                          Ann Arbor
# 0                                    None              None      Ann Arbor
# 0     300 Six Mile Road                                      Whitmore Lake
# 0   2170 Rawsonville Rd                                None     Belleville
#
#    location.zip_code location.country location.state  \
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# ..               ...              ...            ...
# 0              48197               US             MI
# 0              48108               US             MI
# 0              48104               US             MI
# 0              48115               US             MI
# 0              48111               US             MI
#
#                         location.display_address location.cross_streets  \
# 0     [117 W Washington St, Ann Arbor, MI 48104]
# 0     [216 E Washington St, Ann Arbor, MI 48104]
# 0          [216 S State St, Ann Arbor, MI 48104]
# 0           [314 S Main St, Ann Arbor, MI 48104]
# 0        [341 E Liberty St, Ann Arbor, MI 48104]
# ..                                           ...                    ...
# 0         [2955 Packard Rd, Ypsilanti, MI 48197]
# 0      [4741 Washtenaw Ave, Ann Arbor, MI 48108]
# 0                          [Ann Arbor, MI 48104]
# 0   [300 Six Mile Road, Whitmore Lake, MI 48115]
# 0    [2170 Rawsonville Rd, Belleville, MI 48111]
#
#     coordinates.latitude  coordinates.longitude special_hours messaging.url  \
# 0              42.280365             -83.749153           NaN           NaN
# 0              42.280283             -83.746494           NaN           NaN
# 0              42.279605             -83.740965           NaN           NaN
# 0              42.279019             -83.749017           NaN           NaN
# 0              42.279579             -83.744245           NaN           NaN
# ..                   ...                    ...           ...           ...
# 0              42.242075             -83.655158           NaN           NaN
# 0              42.251346             -83.667178           NaN           NaN
# 0              42.267006             -83.727127           NaN           NaN
# 0              42.393310             -83.761600           NaN           NaN
# 0              42.214447             -83.544205           NaN           NaN
#
#    messaging.use_case_text
# 0                      NaN
# 0                      NaN
# 0                      NaN
# 0                      NaN
# 0                      NaN
# ..                     ...
# 0                      NaN
# 0                      NaN
# 0                      NaN
# 0                      NaN
# 0                      NaN
#
# [1000 rows x 30 columns]

# %%
## Clean unused column
aa_details_final = aa_details.iloc[:,:-3]

# %%
aa_details_final
# Out:
#                         id                                         alias  \
# 0   uTMqhmpgfpDMLN3W3YvMeQ                       frita-batidos-ann-arbor
# 0   yNIYH9041m1JEyRS-N_LNw                            aventura-ann-arbor
# 0   Fv2VLzVj9ATLcTbFehTDjg                               savas-ann-arbor
# 0   tZmiwMg9Hdc8PcsKSuWQOg                blue-llama-jazz-club-ann-arbor
# 0   4REtzXpQYy8dVev8RjWbSQ                mani-osteria-and-bar-ann-arbor
# ..                     ...                                           ...
# 0   4ZtSjxdv7lXd_RTCkAbawg  polo-fields-golf-and-country-clubs-ypsilanti
# 0   O7pfu3-HWLHuI8MNZFGOzg          glencoe-lakes-nature-trail-ann-arbor
# 0   4WD8MHDHpl_JFzbmduodyQ                  little-mac-shack-ann-arbor-2
# 0   PU93OtU8LnfW-lB-oBjSDg                        speedway-whitmore-lake
# 0   x61suUXHQFfyTl_fClHIaw                      burger-king-belleville-4
#
#                                 name  \
# 0                      Frita Batidos
# 0                           Aventura
# 0                             Sava's
# 0               Blue LLama Jazz Club
# 0                 Mani Osteria & Bar
# ..                               ...
# 0   Polo Fields Golf & Country Clubs
# 0         Glencoe Lakes Nature Trail
# 0                   Little Mac Shack
# 0                           Speedway
# 0                        Burger King
#
#                                             image_url  is_claimed  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL5...        True      False
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZ...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89...        True      False
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9...        True      False
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/LJscB4...        True      False
# ..                                                ...         ...        ...
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/dzsLMt...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu2...       False      False
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/QKtLUM...       False      False
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/slYlJ7...        True      False
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/40ovUv...        True      False
#
#                                                   url         phone  \
# 0   https://www.yelp.com/biz/frita-batidos-ann-arb...  +17347612882
# 0   https://www.yelp.com/biz/aventura-ann-arbor?ad...  +17343693153
# 0   https://www.yelp.com/biz/savas-ann-arbor?adjus...  +17346232233
# 0   https://www.yelp.com/biz/blue-llama-jazz-club-...  +17343723200
# 0   https://www.yelp.com/biz/mani-osteria-and-bar-...  +17347696700
# ..                                                ...           ...
# 0   https://www.yelp.com/biz/polo-fields-golf-and-...  +17349981555
# 0   https://www.yelp.com/biz/glencoe-lakes-nature-...
# 0   https://www.yelp.com/biz/little-mac-shack-ann-...  +17349975399
# 0   https://www.yelp.com/biz/speedway-whitmore-lak...  +17344498990
# 0   https://www.yelp.com/biz/burger-king-bellevill...  +17344840710
#
#      display_phone  review_count  \
# 0   (734) 761-2882          2145
# 0   (734) 369-3153           857
# 0   (734) 623-2233          1281
# 0   (734) 372-3200           103
# 0   (734) 769-6700           956
# ..             ...           ...
# 0   (734) 998-1555             2
# 0                              1
# 0   (734) 997-5399             1
# 0   (734) 449-8990             2
# 0   (734) 484-0710            11
#
#                                            categories  rating  \
# 0   [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.5
# 0   [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...     4.0
# 0   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 0   [{'alias': 'jazzandblues', 'title': 'Jazz & Bl...     4.5
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# ..                                                ...     ...
# 0   [{'alias': 'golf', 'title': 'Golf'}, {'alias':...     4.0
# 0              [{'alias': 'parks', 'title': 'Parks'}]     3.0
# 0   [{'alias': 'fooddeliveryservices', 'title': 'F...     1.0
# 0   [{'alias': 'servicestations', 'title': 'Gas St...     3.5
# 0   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                                photos price  \
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL...    $$
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/YeASI...   $$$
# 0   [https://s3-media1.fl.yelpcdn.com/bphoto/FZHW8...    $$
# 0   [https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z...   $$$
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/LJscB...    $$
# ..                                                ...   ...
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/dzsLM...   NaN
# 0   [https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu...   NaN
# 0   [https://s3-media2.fl.yelpcdn.com/bphoto/QKtLU...   NaN
# 0   [https://s3-media3.fl.yelpcdn.com/bphoto/7mP8j...   NaN
# 0   [https://s3-media4.fl.yelpcdn.com/bphoto/GQpaD...     $
#
#                                                 hours        transactions  \
# 0   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '1...  [delivery, pickup]
# 0   [{'open': [{'is_overnight': False, 'start': '1...          [delivery]
# ..                                                ...                 ...
# 0   [{'open': [{'is_overnight': False, 'start': '0...                  []
# 0                                                 NaN                  []
# 0                                                 NaN          [delivery]
# 0   [{'open': [{'is_overnight': True, 'start': '00...          [delivery]
# 0   [{'open': [{'is_overnight': False, 'start': '0...          [delivery]
#
#       location.address1 location.address2 location.address3  location.city  \
# 0   117 W Washington St                                          Ann Arbor
# 0   216 E Washington St                                          Ann Arbor
# 0        216 S State St                                          Ann Arbor
# 0         314 S Main St              None                        Ann Arbor
# 0      341 E Liberty St                                          Ann Arbor
# ..                  ...               ...               ...            ...
# 0       2955 Packard Rd                                          Ypsilanti
# 0    4741 Washtenaw Ave                                          Ann Arbor
# 0                                    None              None      Ann Arbor
# 0     300 Six Mile Road                                      Whitmore Lake
# 0   2170 Rawsonville Rd                                None     Belleville
#
#    location.zip_code location.country location.state  \
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# 0              48104               US             MI
# ..               ...              ...            ...
# 0              48197               US             MI
# 0              48108               US             MI
# 0              48104               US             MI
# 0              48115               US             MI
# 0              48111               US             MI
#
#                         location.display_address location.cross_streets  \
# 0     [117 W Washington St, Ann Arbor, MI 48104]
# 0     [216 E Washington St, Ann Arbor, MI 48104]
# 0          [216 S State St, Ann Arbor, MI 48104]
# 0           [314 S Main St, Ann Arbor, MI 48104]
# 0        [341 E Liberty St, Ann Arbor, MI 48104]
# ..                                           ...                    ...
# 0         [2955 Packard Rd, Ypsilanti, MI 48197]
# 0      [4741 Washtenaw Ave, Ann Arbor, MI 48108]
# 0                          [Ann Arbor, MI 48104]
# 0   [300 Six Mile Road, Whitmore Lake, MI 48115]
# 0    [2170 Rawsonville Rd, Belleville, MI 48111]
#
#     coordinates.latitude  coordinates.longitude
# 0              42.280365             -83.749153
# 0              42.280283             -83.746494
# 0              42.279605             -83.740965
# 0              42.279019             -83.749017
# 0              42.279579             -83.744245
# ..                   ...                    ...
# 0              42.242075             -83.655158
# 0              42.251346             -83.667178
# 0              42.267006             -83.727127
# 0              42.393310             -83.761600
# 0              42.214447             -83.544205
#
# [1000 rows x 27 columns]

# %%
# Clean datasets. The "hours" column was messy and not in a string form, so I extracted information from the column and transited it to
# string form. Similar for the "transactions" column
aa_open = []
aa_hour_type = []
aa_is_open_now = []
aa_transactions = []
for i in range(aa_details_final.shape[0]):
    if not isNaN(aa_details_final["hours"].iloc[i]):
        aa_open.append(aa_details_final["hours"].iloc[i][0]["open"])
        aa_hour_type.append(aa_details_final["hours"].iloc[i][0]["hours_type"])
        aa_is_open_now.append(aa_details_final["hours"].iloc[i][0]["is_open_now"])
    else:
        aa_open.append("")
        aa_hour_type.append("")
        aa_is_open_now.append("")
    if (aa_details_final["transactions"].iloc[i] != []) and (not isNaN(aa_details_final["transactions"].iloc[i])):
        aa_transactions.append(aa_details_final["transactions"].iloc[i][0])
    else:
        aa_transactions.append("")

# I stored the info I extracted from "hours" and "transactions" form to new columns of the dataset
aa_details_final["open"] = aa_open
aa_details_final["hour_type"] = aa_hour_type
aa_details_final["is_open_now"] = aa_is_open_now
aa_details_final["transactions"] = aa_transactions
aa_details_final["full_address"] = full_address_aa
aa_details_final.reset_index()
# Out:
#      index                      id  \
# 0        0  uTMqhmpgfpDMLN3W3YvMeQ
# 1        0  yNIYH9041m1JEyRS-N_LNw
# 2        0  Fv2VLzVj9ATLcTbFehTDjg
# 3        0  tZmiwMg9Hdc8PcsKSuWQOg
# 4        0  4REtzXpQYy8dVev8RjWbSQ
# ..     ...                     ...
# 995      0  4ZtSjxdv7lXd_RTCkAbawg
# 996      0  O7pfu3-HWLHuI8MNZFGOzg
# 997      0  4WD8MHDHpl_JFzbmduodyQ
# 998      0  PU93OtU8LnfW-lB-oBjSDg
# 999      0  x61suUXHQFfyTl_fClHIaw
#
#                                             alias  \
# 0                         frita-batidos-ann-arbor
# 1                              aventura-ann-arbor
# 2                                 savas-ann-arbor
# 3                  blue-llama-jazz-club-ann-arbor
# 4                  mani-osteria-and-bar-ann-arbor
# ..                                            ...
# 995  polo-fields-golf-and-country-clubs-ypsilanti
# 996          glencoe-lakes-nature-trail-ann-arbor
# 997                  little-mac-shack-ann-arbor-2
# 998                        speedway-whitmore-lake
# 999                      burger-king-belleville-4
#
#                                  name  \
# 0                       Frita Batidos
# 1                            Aventura
# 2                              Sava's
# 3                Blue LLama Jazz Club
# 4                  Mani Osteria & Bar
# ..                                ...
# 995  Polo Fields Golf & Country Clubs
# 996        Glencoe Lakes Nature Trail
# 997                  Little Mac Shack
# 998                          Speedway
# 999                       Burger King
#
#                                              image_url  is_claimed  is_closed  \
# 0    https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL5...        True      False
# 1    https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZ...        True      False
# 2    https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89...        True      False
# 3    https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9...        True      False
# 4    https://s3-media3.fl.yelpcdn.com/bphoto/LJscB4...        True      False
# ..                                                 ...         ...        ...
# 995  https://s3-media3.fl.yelpcdn.com/bphoto/dzsLMt...        True      False
# 996  https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu2...       False      False
# 997  https://s3-media2.fl.yelpcdn.com/bphoto/QKtLUM...       False      False
# 998  https://s3-media4.fl.yelpcdn.com/bphoto/slYlJ7...        True      False
# 999  https://s3-media1.fl.yelpcdn.com/bphoto/40ovUv...        True      False
#
#                                                    url         phone  \
# 0    https://www.yelp.com/biz/frita-batidos-ann-arb...  +17347612882
# 1    https://www.yelp.com/biz/aventura-ann-arbor?ad...  +17343693153
# 2    https://www.yelp.com/biz/savas-ann-arbor?adjus...  +17346232233
# 3    https://www.yelp.com/biz/blue-llama-jazz-club-...  +17343723200
# 4    https://www.yelp.com/biz/mani-osteria-and-bar-...  +17347696700
# ..                                                 ...           ...
# 995  https://www.yelp.com/biz/polo-fields-golf-and-...  +17349981555
# 996  https://www.yelp.com/biz/glencoe-lakes-nature-...
# 997  https://www.yelp.com/biz/little-mac-shack-ann-...  +17349975399
# 998  https://www.yelp.com/biz/speedway-whitmore-lak...  +17344498990
# 999  https://www.yelp.com/biz/burger-king-bellevill...  +17344840710
#
#       display_phone  review_count  \
# 0    (734) 761-2882          2145
# 1    (734) 369-3153           857
# 2    (734) 623-2233          1281
# 3    (734) 372-3200           103
# 4    (734) 769-6700           956
# ..              ...           ...
# 995  (734) 998-1555             2
# 996                             1
# 997  (734) 997-5399             1
# 998  (734) 449-8990             2
# 999  (734) 484-0710            11
#
#                                             categories  rating  \
# 0    [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.5
# 1    [{'alias': 'tapas', 'title': 'Tapas Bars'}, {'...     4.0
# 2    [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 3    [{'alias': 'jazzandblues', 'title': 'Jazz & Bl...     4.5
# 4    [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# ..                                                 ...     ...
# 995  [{'alias': 'golf', 'title': 'Golf'}, {'alias':...     4.0
# 996             [{'alias': 'parks', 'title': 'Parks'}]     3.0
# 997  [{'alias': 'fooddeliveryservices', 'title': 'F...     1.0
# 998  [{'alias': 'servicestations', 'title': 'Gas St...     3.5
# 999  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
#
#                                                 photos price  \
# 0    [https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL...    $$
# 1    [https://s3-media3.fl.yelpcdn.com/bphoto/YeASI...   $$$
# 2    [https://s3-media1.fl.yelpcdn.com/bphoto/FZHW8...    $$
# 3    [https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z...   $$$
# 4    [https://s3-media3.fl.yelpcdn.com/bphoto/LJscB...    $$
# ..                                                 ...   ...
# 995  [https://s3-media3.fl.yelpcdn.com/bphoto/dzsLM...   NaN
# 996  [https://s3-media1.fl.yelpcdn.com/bphoto/l0BQu...   NaN
# 997  [https://s3-media2.fl.yelpcdn.com/bphoto/QKtLU...   NaN
# 998  [https://s3-media3.fl.yelpcdn.com/bphoto/7mP8j...   NaN
# 999  [https://s3-media4.fl.yelpcdn.com/bphoto/GQpaD...     $
#
#                                                  hours transactions  \
# 0    [{'open': [{'is_overnight': False, 'start': '1...     delivery
# 1    [{'open': [{'is_overnight': False, 'start': '1...     delivery
# 2    [{'open': [{'is_overnight': False, 'start': '1...     delivery
# 3    [{'open': [{'is_overnight': False, 'start': '1...     delivery
# 4    [{'open': [{'is_overnight': False, 'start': '1...     delivery
# ..                                                 ...          ...
# 995  [{'open': [{'is_overnight': False, 'start': '0...
# 996                                                NaN
# 997                                                NaN     delivery
# 998  [{'open': [{'is_overnight': True, 'start': '00...     delivery
# 999  [{'open': [{'is_overnight': False, 'start': '0...     delivery
#
#        location.address1 location.address2 location.address3  location.city  \
# 0    117 W Washington St                                          Ann Arbor
# 1    216 E Washington St                                          Ann Arbor
# 2         216 S State St                                          Ann Arbor
# 3          314 S Main St              None                        Ann Arbor
# 4       341 E Liberty St                                          Ann Arbor
# ..                   ...               ...               ...            ...
# 995      2955 Packard Rd                                          Ypsilanti
# 996   4741 Washtenaw Ave                                          Ann Arbor
# 997                                   None              None      Ann Arbor
# 998    300 Six Mile Road                                      Whitmore Lake
# 999  2170 Rawsonville Rd                                None     Belleville
#
#     location.zip_code location.country location.state  \
# 0               48104               US             MI
# 1               48104               US             MI
# 2               48104               US             MI
# 3               48104               US             MI
# 4               48104               US             MI
# ..                ...              ...            ...
# 995             48197               US             MI
# 996             48108               US             MI
# 997             48104               US             MI
# 998             48115               US             MI
# 999             48111               US             MI
#
#                          location.display_address location.cross_streets  \
# 0      [117 W Washington St, Ann Arbor, MI 48104]
# 1      [216 E Washington St, Ann Arbor, MI 48104]
# 2           [216 S State St, Ann Arbor, MI 48104]
# 3            [314 S Main St, Ann Arbor, MI 48104]
# 4         [341 E Liberty St, Ann Arbor, MI 48104]
# ..                                            ...                    ...
# 995        [2955 Packard Rd, Ypsilanti, MI 48197]
# 996     [4741 Washtenaw Ave, Ann Arbor, MI 48108]
# 997                         [Ann Arbor, MI 48104]
# 998  [300 Six Mile Road, Whitmore Lake, MI 48115]
# 999   [2170 Rawsonville Rd, Belleville, MI 48111]
#
#      coordinates.latitude  coordinates.longitude  \
# 0               42.280365             -83.749153
# 1               42.280283             -83.746494
# 2               42.279605             -83.740965
# 3               42.279019             -83.749017
# 4               42.279579             -83.744245
# ..                    ...                    ...
# 995             42.242075             -83.655158
# 996             42.251346             -83.667178
# 997             42.267006             -83.727127
# 998             42.393310             -83.761600
# 999             42.214447             -83.544205
#
#                                                   open hour_type is_open_now  \
# 0    [{'is_overnight': False, 'start': '1100', 'end...   REGULAR       False
# 1    [{'is_overnight': False, 'start': '1500', 'end...   REGULAR       False
# 2    [{'is_overnight': False, 'start': '1100', 'end...   REGULAR       False
# 3    [{'is_overnight': False, 'start': '1800', 'end...   REGULAR       False
# 4    [{'is_overnight': False, 'start': '1600', 'end...   REGULAR       False
# ..                                                 ...       ...         ...
# 995  [{'is_overnight': False, 'start': '0730', 'end...   REGULAR       False
# 996
# 997
# 998  [{'is_overnight': True, 'start': '0000', 'end'...   REGULAR        True
# 999  [{'is_overnight': False, 'start': '0600', 'end...   REGULAR        True
#
#                                   full_address
# 0      117 W Washington St Ann Arbor, MI 48104
# 1      216 E Washington St Ann Arbor, MI 48104
# 2           216 S State St Ann Arbor, MI 48104
# 3            314 S Main St Ann Arbor, MI 48104
# 4         341 E Liberty St Ann Arbor, MI 48104
# ..                                         ...
# 995        2955 Packard Rd Ypsilanti, MI 48197
# 996     4741 Washtenaw Ave Ann Arbor, MI 48108
# 997                        Ann Arbor, MI 48104
# 998  300 Six Mile Road Whitmore Lake, MI 48115
# 999   2170 Rawsonville Rd Belleville, MI 48111
#
# [1000 rows x 32 columns]

# %%
# Transform the dataframe to a csv
aa_details_final.to_csv("AA_Yelp_details.csv")

# %%
from fuzzywuzzy import process
import warnings
warnings.filterwarnings('ignore')

# %%
# importing the data

aa_yelp = pd.read_csv("AA_Yelp_details.csv", comment="#")
aa_clct_common = pd.read_csv("aa_clct_common.csv", comment="#")
aa_clct_uncommon = pd.read_csv("aa_clct_uncommon.csv", comment="#")
aa_resid = pd.read_csv("aa_resid.csv", comment="#")
aa_common = pd.read_csv("aa_common.csv", comment="#")
aa_uncommon = pd.read_csv("aa_uncommon.csv", comment="#")

# %%
# define all the neccessary functions in the data cleaning and merging process

def merge_dataframes(*args):
    concat = pd.concat(args)
    
    return concat

def remove_standard_duplicates(concat):
    merged = concat.drop_duplicates(subset=['Name', 'Address'])
    merged = merged.drop(columns=['Unnamed: 0'])
    #merged = merged[[merged.columns[0], merged.columns[1], merged.columns[2]]]
    
    return merged


def remove_fuzzy_duplicates(merged):
    merged['Name + Address'] = merged['Name'] + merged['Address']
    merged = merged.astype(str)
    unique_strings = list(merged['Name + Address'].unique())
    merged['second_best_match'] = merged['Name + Address'].apply(lambda x: process.extract(x, unique_strings, limit=2)[1][0])
    merged['second_best_score'] = merged['Name + Address'].apply(lambda x: process.extract(x, unique_strings, limit=2)[1][1])
    potential_matches = merged.loc[merged['second_best_score'] >= 92]
    potential_matches = potential_matches.sort_values('Name')
    potential_matches = potential_matches.drop(potential_matches.index[::2])
    complete = merged.loc[merged['second_best_score'] < 92]
    complete = complete.append(potential_matches)
    
    return complete

# creating two new columns for latitude and longitude
def lat_lng(df):
    lat = []
    long = []
    for i in range(len(df)):
        if isNaN(df['Coordinates'][i]):
            df['Coordinates'][i] = "{'lat': None, 'lng': None}"
        df['Coordinates'][i] = eval(df['Coordinates'][i])
        try:
            lat.append(df['Coordinates'][i]['lat'])
            long.append(df['Coordinates'][i]['lng'])
        except:
            lat.append(df['Coordinates'][i]['latitude'])
            long.append(df['Coordinates'][i]['longitude'])
    df['Latitude'] = lat
    df['Longitude'] = long

# %%
# recode all coordinates
lat_lng(aa_common)
lat_lng(aa_uncommon)
lat_lng(aa_clct_common)
lat_lng(aa_clct_uncommon)
lat_lng(aa_resid)

# %%
# recode yelp location type
for i in range(len(aa_yelp)):
    lst = eval(aa_yelp['categories'][i])
    type_list = []
    for j in range(len(lst)):
        type_list.append(lst[j]['alias'])
    aa_yelp['categories'][i] = type_list

# %%
# rename columns for consistency
aa_yelp = aa_yelp.rename(columns={
    'name': 'Name',
    'coordinates.latitude': 'Latitude',
    'coordinates.longitude': 'Longitude',
    'categories': 'category',
    'full_address': 'Address',
    'is_closed': 'business_status',
    'review_count': 'user_ratings_total',
    'price': 'price_level'
})

# %%
# as the first step of merging,
# merge and drop standard duplicates
aa_merged = merge_dataframes(aa_yelp, aa_clct_common, aa_clct_uncommon, aa_resid, aa_common, aa_uncommon)
aa_merged_clean = remove_standard_duplicates(aa_merged)

# %%
# drop blank columns
aa_merged_clean = aa_merged_clean.drop(
    ['alias', 'is_claimed', 'phone', 'transactions', 'location.address1', 
        'location.address2', 'location.address3', 'location.city', 'location.zip_code',
        'location.country', 'location.state', 'location.display_address', 'location.cross_streets', 
        'open', 'is_open_now', 'delivery', 'dine_in', 'takeout', 'serves_breakfast',
        'serves_brunch', 'serves_lunch', 'serves_dinner', 'serves_vegetarian_food', 'serves_beer', 'serves_wine',
        'types', 'Coordinates'
    ]
    , axis=1)

# %%
# fuzzywuzzy
# note this cell takes a long time to run
aa_merged_clean = remove_fuzzy_duplicates(aa_merged_clean)

# %%
aa_merged_clean.head()
# Out:
#                        id                  Name  \
# 0  uTMqhmpgfpDMLN3W3YvMeQ         Frita Batidos
# 1  yNIYH9041m1JEyRS-N_LNw              Aventura
# 2  Fv2VLzVj9ATLcTbFehTDjg                Sava's
# 3  tZmiwMg9Hdc8PcsKSuWQOg  Blue LLama Jazz Club
# 4  4REtzXpQYy8dVev8RjWbSQ    Mani Osteria & Bar
#
#                                            image_url business_status  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/ZbbAL5...           False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/YeASIZ...           False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/FZHW89...           False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/vcn9Z9...           False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/LJscB4...           False
#
#                                                  url   display_phone  \
# 0  https://www.yelp.com/biz/frita-batidos-ann-arb...  (734) 761-2882
# 1  https://www.yelp.com/biz/aventura-ann-arbor?ad...  (734) 369-3153
# 2  https://www.yelp.com/biz/savas-ann-arbor?adjus...  (734) 623-2233
# 3  https://www.yelp.com/biz/blue-llama-jazz-club-...  (734) 372-3200
# 4  https://www.yelp.com/biz/mani-osteria-and-bar-...  (734) 769-6700
#
#   user_ratings_total                                        category rating  \
# 0             2145.0                            ['cuban', 'burgers']    4.5
# 1              857.0                    ['tapas', 'spanish', 'bars']    4.0
# 2             1281.0    ['bars', 'breakfast_brunch', 'tradamerican']    4.0
# 3              103.0  ['jazzandblues', 'musicvenues', 'newamerican']    4.5
# 4              956.0            ['italian', 'pizza', 'cocktailbars']    4.0
#
#                                               photos price_level  \
# 0  ['https://s3-media3.fl.yelpcdn.com/bphoto/ZbbA...          $$
# 1  ['https://s3-media3.fl.yelpcdn.com/bphoto/YeAS...         $$$
# 2  ['https://s3-media1.fl.yelpcdn.com/bphoto/FZHW...          $$
# 3  ['https://s3-media2.fl.yelpcdn.com/bphoto/vcn9...         $$$
# 4  ['https://s3-media3.fl.yelpcdn.com/bphoto/LJsc...          $$
#
#                                                hours          Latitude  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...        42.2803651
# 1  [{'open': [{'is_overnight': False, 'start': '1...         42.280283
# 2  [{'open': [{'is_overnight': False, 'start': '1...         42.279605
# 3  [{'open': [{'is_overnight': False, 'start': '1...         42.279019
# 4  [{'open': [{'is_overnight': False, 'start': '1...  42.2795793749763
#
#           Longitude hour_type                                  Address  \
# 0       -83.7491532   REGULAR  117 W Washington St Ann Arbor, MI 48104
# 1        -83.746494   REGULAR  216 E Washington St Ann Arbor, MI 48104
# 2       -83.7409649   REGULAR       216 S State St Ann Arbor, MI 48104
# 3        -83.749017   REGULAR        314 S Main St Ann Arbor, MI 48104
# 4  -83.744244702611   REGULAR     341 E Liberty St Ann Arbor, MI 48104
#
#   place_id business_hours business_hours_text  \
# 0      nan            nan                 nan
# 1      nan            nan                 nan
# 2      nan            nan                 nan
# 3      nan            nan                 nan
# 4      nan            nan                 nan
#
#                                       Name + Address  \
# 0  Frita Batidos117 W Washington St Ann Arbor, MI...
# 1    Aventura216 E Washington St Ann Arbor, MI 48104
# 2           Sava's216 S State St Ann Arbor, MI 48104
# 3  Blue LLama Jazz Club314 S Main St Ann Arbor, M...
# 4  Mani Osteria & Bar341 E Liberty St Ann Arbor, ...
#
#                                    second_best_match  second_best_score
# 0  University of Michigan Museum of Natural Histo...                 86
# 1        Mash211 E Washington St Ann Arbor, MI 48104                 87
# 2       aMa Bistro215 S State St Ann Arbor, MI 48104                 88
# 3  University of Michigan Museum of Natural Histo...                 86
# 4               Eat407 N 5th Ave Ann Arbor, MI 48104                 86

# %%
aa_sites = aa_merged_clean.copy()
# for 'FALSE'/'False' in business_status, change it to 'OPERATIONAL'
aa_sites['business_status'] = aa_sites['business_status'].replace('FALSE', 'OPERATIONAL')
aa_sites['business_status'] = aa_sites['business_status'].replace('False', 'OPERATIONAL')
# rename columns so that we can distinguish google id and yelp id
aa_sites.rename(columns={'place_id': 'google_id', 'id': 'yelp_id'}, inplace=True)

# %%
name_counts = pd.DataFrame(aa_sites['Name'].value_counts())
name_counts[name_counts['Name'] > 2]
# look for chains that might be local that I'd be unfamiliar with (do a quick google search to see what they look like)
# note that this is just for my own exploration
# this code do not have any impact on the final dataset
# Out:
#                                      Name
# Starbucks                              22
# Zipcar                                 19
# Subway                                 18
# McDonald's                             16
# Jimmy John's                           14
# ...                                   ...
# Noodles & Company                       3
# Blue Café                               3
# Detroit Wing Company                    3
# Red Robin Gourmet Burgers and Brews     3
# Kroger                                  3
#
# [64 rows x 1 columns]

# %%
# Ellie wants a FUE-only dataset, so here we do an extra step of filtering
aa_FUEs = aa_sites[(
    (aa_sites['category'] == 'bar') | (aa_sites['category'] == 'cafe') | 
    (aa_sites['category'] == 'food') | (aa_sites['category'] == 'restaurant') |
    (aa_sites['category'] == 'bakery') | (aa_sites['category'] == 'meal_delivery') |
    (aa_sites['category'] == 'meal_takeaway') | (aa_sites['category'] == 'convenience_store') |
    (aa_sites['category'] == 'school') | (aa_sites['category'] == 'grocery_or_supermarket') |
    (aa_sites['category'] == 'university') | (aa_sites['category'] == 'supermarket') |
    (aa_sites['category'] == 'secondary_school') | (aa_sites['category'] == 'primary_school') |
    (aa_sites['category'] == 'airport') | (aa_sites['category'] == 'amusement_park') |
    (aa_sites['category'] == 'aquarium') | (aa_sites['category'] == 'movie_theater') )]

# %%
# final step!
# save everything!
aa_FUEs.to_csv('aa_FUEs.csv')
aa_sites.to_csv('aa_complete.csv')

# %%
len(aa_sites)
# this is the length of aa_sites with duplicates
# Out:
# 3180

# %%
# save a copy of aa_sites in case i mess up with something later
aa_sites_copy = aa_sites.copy()

# %%
# now we do some exploration to avoid the manual checking and removing duplicates process
# since 1 degree longtitude is 111 km, we know that 0.00001 degree is about 1 meter
# we try rounding the coordinates and use that as a standard to drop duplicates

# first transform the coordinates to float
aa_sites['Latitude'] = aa_sites['Latitude'].astype(float)
aa_sites['Longitude'] = aa_sites['Longitude'].astype(float)

# then round the coordinates
aa_sites['Latitude'] = aa_sites['Latitude'].round(5)
aa_sites['Longitude'] = aa_sites['Longitude'].round(5)

# %%
# then drop duplicates
aa_sites.drop_duplicates(subset=['Latitude', 'Longitude'], inplace=True)

# %%
len(aa_sites)

# note that our manual dropping left us with 2650 rows
# here this method left us with 2849 rows
# which means that rounding the coordinates to 5 digits as a criteria is actually good
# Out:
# 2849

# %% [markdown]
# # Below is the extra processing I did after manual cleaning

# %%
aa_sites = pd.read_csv('../data/aa_complete.csv', comment="#")

# %%
aa_sites.shape
# Out:
# (2650, 24)

# %%
# display max columns
pd.set_option('display.max_columns', None)
aa_sites.head()
# Out:
#    Unnamed: 0                 yelp_id                        Name  \
# 0         201  C8IeolsUWU0MWFY0aCEdRg                        1923
# 1         989  xE2I0C6uWcx2mstg-j45yA                ¡Whoa! Tacos
# 2          93                     NaN    100 E Hoover Ave Parking
# 3          27                     NaN    100-198 E Ann St Parking
# 4           7                     NaN  100-198 S Maple Rd Parking
#
#                                            image_url business_status  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/chingD...     OPERATIONAL
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/t0TidF...     OPERATIONAL
# 2                                                NaN     OPERATIONAL
# 3                                                NaN     OPERATIONAL
# 4                                                NaN     OPERATIONAL
#
#                                                  url   display_phone  \
# 0  https://www.yelp.com/biz/1923-ann-arbor?adjust...  (734) 934-0969
# 1  https://www.yelp.com/biz/whoa-tacos-metro-detr...  (734) 716-2646
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    user_ratings_total                             category  rating  \
# 0                 8.0              ['tacos', 'foodtrucks']     5.0
# 1                 3.0  ['foodtrucks', 'catering', 'tacos']     3.5
# 2                 NaN                              parking     NaN
# 3                 NaN                              parking     NaN
# 4                 NaN                              parking     NaN
#
#                                               photos price_level  \
# 0  ['https://s3-media3.fl.yelpcdn.com/bphoto/chin...         NaN
# 1  ['https://s3-media3.fl.yelpcdn.com/bphoto/t0Ti...         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#                                                hours   Latitude  Longitude  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...  42.283480 -83.751040
# 1  [{'open': [{'is_overnight': False, 'start': '0...  42.358002 -83.214996
# 2                                                NaN  42.269023 -83.748427
# 3                                                NaN  42.281999 -83.747725
# 4                                                NaN  42.279602 -83.781810
#
#   hour_type                             Address                    google_id  \
# 0   REGULAR  320 Miller Ave Ann Arbor, MI 48103                          NaN
# 1   REGULAR             Metro Detroit, MI 48393                          NaN
# 2       NaN  140E East Hoover Avenue, Ann Arbor  ChIJ1dF5bTGuPIgRiV9otUqoNdQ
# 3       NaN         100-198 E Ann St, Ann Arbor  ChIJjWxe7T2uPIgRmH_UgIrnwLk
# 4       NaN       100-198 S Maple Rd, Ann Arbor  ChIJl0oozcCxPIgRJKsvEdXECeI
#
#   business_hours business_hours_text  \
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
#                                       Name + Address  \
# 0             1923320 Miller Ave Ann Arbor, MI 48103
# 1                ¡Whoa! TacosMetro Detroit, MI 48393
# 2  100 E Hoover Ave Parking140E East Hoover Avenu...
# 3  100-198 E Ann St Parking100-198 E Ann St, Ann ...
# 4  100-198 S Maple Rd Parking100-198 S Maple Rd, ...
#
#                                    second_best_match  second_best_score  \
# 0  Vinology Restaurant & Event Space110 S Main St...                 86
# 1  Frita Batidos117 W Washington St Ann Arbor, MI...                 86
# 2             eat1906 Packard St Ann Arbor, MI 48104                 86
# 3  100-198 S Maple Rd Parking100-198 S Maple Rd, ...                 87
# 4  100-198 E Ann St Parking100-198 E Ann St, Ann ...                 87
#
#    hours_open
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
eval(aa_sites['category'][0])
# Out:
# ['tacos', 'foodtrucks']

# %%
# we loop through the category column and extract the first element of each list
# if there is only a single element, we leave it as it is
category_list = []
for i in aa_sites['category']:
    try:
        values = eval(i)
        category_list.append(values[0])
    except:
        category_list.append(i)
        continue

# %%
aa_sites['main_category'] = category_list
aa_sites.to_csv('aa_complete.csv')

# %% [markdown]
# # Below is the extra processing for a FUE-only CSV file

# %%
import pandas as pd
aa_full_biz = pd.read_csv('../data/complete_data_files/aa_complete.csv', comment="#")

# %%
t = aa_full_biz['main_category'].values
t = t.tolist()
t = list(set(t))
t
# Out:
# [nan,
#  'skate_parks',
#  'vegan',
#  'shoe_store',
#  'car_dealer',
#  'grocery',
#  'supermarket',
#  'breweries',
#  'gourmet',
#  'icecream',
#  'beer_and_wine',
#  'gym',
#  'fooddeliveryservices',
#  'szechuan',
#  'jewelry_store',
#  'veterinary_care',
#  'hotdog',
#  'general_contractor',
#  'dog_parks',
#  'burgers',
#  'golf',
#  'halal',
#  'grocery_or_supermarket',
#  'korean',
#  'bicycle_store',
#  'seafood',
#  'pizza',
#  'cafeteria',
#  'localflavor',
#  'landmarks',
#  'hardware_store',
#  'tradamerican',
#  'health',
#  'hiking',
#  'bars',
#  'yelpevents',
#  'mexican',
#  'secondary_school',
#  'bus_station',
#  'bakery',
#  'neighborhood',
#  'courthouse',
#  'vinyl_records',
#  'vegetarian',
#  'physiotherapist',
#  'coffee',
#  'farmersmarket',
#  'german',
#  'cemetery',
#  'tourist_attraction',
#  'pubs',
#  'furniture_store',
#  'gas_station',
#  'food',
#  'cuban',
#  'dogwalkers',
#  'liquor_store',
#  'tobaccoshops',
#  'taxi_stand',
#  'parks',
#  'church',
#  'insurance_agency',
#  'buffets',
#  'store',
#  'educationservices',
#  'pet_store',
#  'diners',
#  'atm',
#  'dentist',
#  'venues',
#  'mosque',
#  'restaurants',
#  'cupcakes',
#  'movie_theater',
#  'publicart',
#  'parking',
#  'finance',
#  'library',
#  'bowling_alley',
#  'caribbean',
#  'meats',
#  'lawyer',
#  'zoos',
#  'fire_station',
#  'plumber',
#  'transit_station',
#  'mediterranean',
#  'lodging',
#  'synagogue',
#  'place_of_worship',
#  'soulfood',
#  'boating',
#  'stadium',
#  'chickenshop',
#  'servicestations',
#  'noodles',
#  'beerbar',
#  'divebars',
#  'indpak',
#  'bar',
#  'italian',
#  'foodtrucks',
#  'coffeeroasteries',
#  'irish_pubs',
#  'bubbletea',
#  'chicken_wings',
#  'vietnamese',
#  'gelato',
#  'drugstore',
#  'mideastern',
#  'sandwiches',
#  'electronics_store',
#  'comedyclubs',
#  'car_repair',
#  'gardens',
#  'himalayan',
#  'convenience_store',
#  'hospital',
#  'premise',
#  'university',
#  'accounting',
#  'point_of_interest',
#  'bbq',
#  'school',
#  'painter',
#  'museums',
#  'juicebars',
#  'post_office',
#  'meal_delivery',
#  'breakfast_brunch',
#  'donuts',
#  'whiskeybars',
#  'primary_school',
#  'greek',
#  'hotdogs',
#  'movietheaters',
#  'streetvendors',
#  'funeral_home',
#  'desserts',
#  'shopping_mall',
#  'creperies',
#  'steak',
#  'locality',
#  'tapasmallplates',
#  'wraps',
#  'newamerican',
#  'clothing_store',
#  'pharmacy',
#  'chocolate',
#  'asianfusion',
#  'cafes',
#  'lounges',
#  'delis',
#  'tacos',
#  'cafe',
#  'meal_takeaway',
#  'sushi',
#  'poolhalls',
#  'airport',
#  'laundry',
#  'playgrounds',
#  'local_government_office',
#  'hair_care',
#  'pancakes',
#  'restaurant',
#  'brewpubs',
#  'cheesesteaks',
#  'cookingschools',
#  'doctor',
#  'thai',
#  'african',
#  'chinese',
#  'book_store',
#  'movie_rental',
#  'bakeries',
#  'moving_company',
#  'park',
#  'electrician',
#  'convenience',
#  'sportsbars',
#  'latin',
#  'ethiopian',
#  'poke',
#  'lebanese',
#  'salad',
#  'storage',
#  'real_estate_agency',
#  'department_store',
#  'beauty_salon',
#  'kosher',
#  'cocktailbars',
#  'bank',
#  'japanese']

# %%
non_FUE = ['skate_parks', 'shoe_store', 'car_dealer', 'gym', 'jewelry_store',
           'veterinary_care', 'general_contractor', 'dog_parks', 'golf', 'bicycle_store',
           'landmarks', 'hardware_store', 'health', 'hiking', 'yelpevents', 'bus_station',
            'neighborhood',  'courthouse', 'vinyl_records', 'physiotherapist', 'cemetery',
            'tourist_attraction',  'furniture_store', 'gas_station', 'dogwalkers', 'tobaccoshops',
            'taxi_stand', 'parks', 'church', 'insurance_agency', 'store', 'educationservices', 
            'pet_store', 'atm', 'dentist', 'venues', 'mosque', 'publicart', 'parking', 'finance',
            'library', 'bowling_alley', 'lawyer', 'zoos', 'fire_station', 'plumber', 'transit_station',
            'lodging', 'synagogue', 'place_of_worship', 'boating', 'stadium', 'servicestations', 'divebars',
            'indpak', 'drugstore', 'electronics_store', 'car_repair', 'gardens', 'premise', 
            'accounting', 'point_of_interest', 'painter', 'museums', 'post_office', 'funeral_home',
            'locality', 'clothing_store', 'pharmacy', 'poolhalls', 'laundry', 'playgrounds', 'local_government_office',
            'hair_care', 'doctor', 'book_store', 'movie_rental', 'moving_company', 'park', 'electrician',
             'storage', 'real_estate_agency', 'department_store', 'beauty_salon', 'bank'
           ]

# %%
# filter all FUEs
# they are businesses whose main_category is not in the non_FUE list
aa_FUEs = aa_full_biz[~aa_full_biz['main_category'].isin(non_FUE)]

# %%
aa_FUEs.reset_index(drop=True, inplace=True)

# %%
# save as a csv
aa_FUEs.to_csv('../data/FUE_only_data_files/aa_FUEs.csv')
