# %% [markdown]
# #### This jupyter notebook is made by Ziyu. I reran her notebook to update best sites for map-making.
# #### You can go to Ziyu's branch for more details about this jupyter notebook

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# import API-related libraries
import requests
import json
import time #will use this to pause execution for a few seconds

# suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load & Process Dataframes

# %%
# creating one data set with centers and buffers for each cluster
## read files, you can find these two files in the output directory (I made in the Galveston_kmean_collection_points_final_60_point.ipynb)
galv_centers = gpd.read_file('galveston_parcel_cluster_center_60.geojson')
galv_buffers = gpd.read_file('galveston_parcel_cluster_buffer_60.geojson')

# create a combined dataframe containing both centroids and buffers
galv_centers = galv_centers.rename(columns = {'geometry' : 'center'})
galv_clusters = galv_centers.assign(buffer = galv_buffers['geometry'])

galv_clusters['site_name'] = np.nan
galv_clusters['site_location'] = np.nan
galv_clusters['site_dist'] = np.nan
galv_clusters.head()
# Out:
#          lat       long                      center  \
# 0  29.201904 -94.944011  POINT (-94.94401 29.20190)
# 1  29.298048 -94.819682  POINT (-94.81968 29.29805)
# 2  29.131075 -95.061183  POINT (-95.06118 29.13107)
# 3  29.264259 -94.877844  POINT (-94.87784 29.26426)
# 4  29.339165 -94.790654  POINT (-94.79065 29.33916)
#
#                                               buffer  site_name  \
# 0  POLYGON ((-94.94001 29.20190, -94.94003 29.201...        NaN
# 1  POLYGON ((-94.81568 29.29805, -94.81570 29.297...        NaN
# 2  POLYGON ((-95.05718 29.13107, -95.05720 29.130...        NaN
# 3  POLYGON ((-94.87384 29.26426, -94.87386 29.263...        NaN
# 4  POLYGON ((-94.78665 29.33916, -94.78667 29.338...        NaN
#
#    site_location  site_dist
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN

# %%
# Load the distribution points dataframe
dist = pd.read_csv("complete_galveston.csv")
dist.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0                                            Name  \
# 0             0           0  Moody Gardens Hotel, Spa and Convention Center
# 1             1           1                                 Rainforest Cafe
# 2             2           2                 Landry's Prime Seafood & Steaks
#
#                              Address  \
# 0        7 Hope Boulevard, Galveston
# 1  5310 Seawall Boulevard, Galveston
# 2  5310 Seawall Boulevard, Galveston
#
#                                       Coordinates  \
# 0  {'lat': 29.2734603, 'lng': -94.85032249999999}
# 1         {'lat': 29.2707531, 'lng': -94.8202072}
# 2         {'lat': 29.2707352, 'lng': -94.8202317}
#
#                                       Name + Address  \
# 0  Moody Gardens Hotel, Spa and Convention Center...
# 1   Rainforest Cafe5310 Seawall Boulevard, Galveston
# 2  Landry's Prime Seafood & Steaks5310 Seawall Bo...
#
#                                    second_best_match  second_best_score
# 0   Rainforest Cafe5310 Seawall Boulevard, Galveston                 86
# 1  Moody Gardens Hotel, Spa and Convention Center...                 86
# 2  Landry's Prime Seafood & Steaks5310 Seawall Bl...                 88

# %%
# Load the collection points dataframe
clct = pd.read_csv('complete_galveston2.csv')

# manipuate to make sure clct has the same strcture as dist
# for the ease of later combining
clct['Unnamed: 0.1'] = ['-']*len(clct)
first_col= clct.pop('Unnamed: 0.1')
clct.insert(0,'Unnamed: 0.1',first_col)

# look at dataframe
clct.head(3)
# Out:
#   Unnamed: 0.1  Unnamed: 0                           Name  \
# 0            -           2  3018 Texas Clipper Rd Parking
# 1            -           3                    Parking lot
# 2            -           4        East Beach Free Parking
#
#                               Address  \
# 0  3018 Texas Clipper Road, Galveston
# 1                           Galveston
# 2         Apffel Park Road, Galveston
#
#                                       Coordinates  \
# 0  {'lat': 29.3157226, 'lng': -94.81716879999999}
# 1  {'lat': 29.3353876, 'lng': -94.77805839999999}
# 2          {'lat': 29.325156, 'lng': -94.7386875}
#
#                                       Name + Address  \
# 0  3018 Texas Clipper Rd Parking3018 Texas Clippe...
# 1                               Parking lotGalveston
# 2  East Beach Free ParkingApffel Park Road, Galve...
#
#                                    second_best_match  second_best_score
# 0         Parking utmb365-379 11th Street, Galveston                 86
# 1         Parking utmb365-379 11th Street, Galveston                 86
# 2  UTMB - Public Parking, Galveston Hospitals200 ...                 86

# %%
# Combine distribution and collection points to get a complete dataframe of all businesses
complete = pd.concat([dist, clct], ignore_index=True)
complete.head(3)
# Out:
#   Unnamed: 0.1  Unnamed: 0                                            Name  \
# 0            0           0  Moody Gardens Hotel, Spa and Convention Center
# 1            1           1                                 Rainforest Cafe
# 2            2           2                 Landry's Prime Seafood & Steaks
#
#                              Address  \
# 0        7 Hope Boulevard, Galveston
# 1  5310 Seawall Boulevard, Galveston
# 2  5310 Seawall Boulevard, Galveston
#
#                                       Coordinates  \
# 0  {'lat': 29.2734603, 'lng': -94.85032249999999}
# 1         {'lat': 29.2707531, 'lng': -94.8202072}
# 2         {'lat': 29.2707352, 'lng': -94.8202317}
#
#                                       Name + Address  \
# 0  Moody Gardens Hotel, Spa and Convention Center...
# 1   Rainforest Cafe5310 Seawall Boulevard, Galveston
# 2  Landry's Prime Seafood & Steaks5310 Seawall Bo...
#
#                                    second_best_match  second_best_score
# 0   Rainforest Cafe5310 Seawall Boulevard, Galveston                 86
# 1  Moody Gardens Hotel, Spa and Convention Center...                 86
# 2  Landry's Prime Seafood & Steaks5310 Seawall Bl...                 88

# %%
# There are several rows with empty coordinates
# We need to drop them before proceeding
complete.dropna(axis=0, how = 'any', inplace=True)

# after dropping, we need to reset the index
complete['order'] = [i for i in range(0,len(complete))]
complete = complete.set_index("order")

# %%
# view the shape of the cleaned dataframe
complete.shape
# Out:
# (2961, 8)

# %%
# Create two columns of coordinates in the complete dataframe for the ease of computation
lats = []
longs  = []

# loop through the dataframe
for i in range(0,len(complete)):
    
    # get the content in each cell
    coordinate = complete['Coordinates'][i]
    
    # transform string to a dictionary
    coordinate = eval(coordinate)
    
    # get latitudes (keys are different: some are "lat" and some are "latitude")
    # so we have to use "next(iter(coordinate))"
    lat = coordinate[next(iter(coordinate))]
    
    # get longtitudes
    long = list(coordinate.values())[1]
    
    # append to the bigger list
    lats.append(lat)
    longs.append(long)

# create columns for lat and long
complete['lats'] = lats
complete['longs'] = longs

# %%
# make it a geo df
complete = gpd.GeoDataFrame(complete, geometry=gpd.points_from_xy(complete.longs, complete.lats))
# only select columns we need for later use
complete = complete[['Name', 'Address', 'geometry', 'lats', 'longs']]
complete = complete.rename(columns = {'geometry':'Coordinates'})
complete.head(3)
# Out:
#                                                  Name  \
# order
# 0      Moody Gardens Hotel, Spa and Convention Center
# 1                                     Rainforest Cafe
# 2                     Landry's Prime Seafood & Steaks
#
#                                  Address                 Coordinates  \
# order
# 0            7 Hope Boulevard, Galveston  POINT (-94.85032 29.27346)
# 1      5310 Seawall Boulevard, Galveston  POINT (-94.82021 29.27075)
# 2      5310 Seawall Boulevard, Galveston  POINT (-94.82023 29.27074)
#
#             lats      longs
# order
# 0      29.273460 -94.850322
# 1      29.270753 -94.820207
# 2      29.270735 -94.820232

# %%
complete.to_csv("All_Galveston_Business.csv")

# %% [markdown]
# # ---------------------------------------------
# # Using Mapbox Matrix API

# %%
# My access token to mapbox matrix api
# replace it with yours if you are using my code later
token = "pk.eyJ1IjoiYXNobGV5eml5dXJlbiIsImEiOiJjbGU3a2JncGswNmJwM25wN3Rwa211bG04In0.pGiFstl_qOeFnehPWJhhww"

# %%
import time #will use this to pause execution for a few seconds

# %%
# finding closest business to each cluster centroid within the cluster boundaries
# this closest business will serve as the actual colletion site (because our centroids are merely theoratical)
# The code below searches within the boundaries for each cluster

for idx in range(len(galv_clusters)):  
    boundary = galv_clusters['buffer'][idx]
    #identify sites within the cluster boundaries
    within_boundary = complete[complete.Coordinates.within(boundary)].reset_index(drop = True)
    
    #rest of the code is the same as above basically
    nearby = within_boundary
    distances = []
    
    #added this if len(nearby) > 0 bc of the troublesome cases where filtering was inaccurate and nothing was nearby
    if len(nearby) > 0:
        # mapbox matrix api can take no more than 25 locations each time
        # we can search for the first 25 stores first
        while len(nearby) > 24:
            short_list = nearby.head(24)
            nearby = nearby[24:].reset_index(drop = True)
            
            coord = str(galv_clusters['long'][idx]) + "," + str(galv_clusters['lat'][idx])
            for i in range(len(short_list)):
                coord = coord + ";" + str(short_list['longs'][i]) +  "," + str(short_list['lats'][i])
                
            url = "https://api.mapbox.com/directions-matrix/v1/mapbox/walking/" +\
                    coord + "?sources=0&annotations=distance,duration"
            r = requests.get(url, params=({'access_token':token}))
            r =  json.loads(r.content)
            time.sleep(2) # no more than 60 requests per minute, so we need to put it to sleep

            for d in r['durations'][0][1:]:
                distances.append(d)
        # then we can search for the rest of stores (if there is less than 25 stores, the code will directly go to this part)    
        coord = str(galv_clusters['long'][idx]) + "," + str(galv_clusters['lat'][idx])
        for i in range(len(nearby)):
            coord = coord + ";" + str(nearby['longs'][i]) +  "," + str(nearby['lats'][i])
        url = "https://api.mapbox.com/directions-matrix/v1/mapbox/walking/" +\
                coord + "?sources=0&annotations=distance,duration"

        r = requests.get(url, params=({'access_token':token}))
        r =  json.loads(r.content)

        for d in r['durations'][0][1:]:
            distances.append(d)
        
        # attach the distances we found to the within-boundary businesses df
        within_boundary = within_boundary.assign(Dist = distances)
        # finding the closest one
        closest = within_boundary[within_boundary.Dist == within_boundary.Dist.min()]

        # attach to the bigger centroid df
        galv_clusters['site_name'][idx] = closest['Name'].values[0]
        galv_clusters['site_location'][idx] = closest['Coordinates'].values[0]
        galv_clusters['site_dist'][idx] = closest['Dist'].values[0]
        
    # if there is no nearby businesses found, the code will directly go the this part below
    else:
        galv_clusters['site_name'][idx] = np.nan
        galv_clusters['site_location'][idx] = np.nan
        galv_clusters['site_dist'][idx] = np.nan

# %%
# filter out those clusters where there is no nearby business
galv_clusters_nan = galv_clusters[galv_clusters['site_name'].isnull()]
galv_clusters_nan = galv_clusters_nan.reset_index()
# also filter out those clusters where we have already found the nearby business
galv_clusters_found = galv_clusters[galv_clusters['site_name'].notnull()]

# %%
# create a copy of the complete business df
complete_copy = complete

# finding closest dist or collection site for each cluster center where there were no sites within the boundary

for idx in range(len(galv_clusters_nan)):  
    print(idx)
    nearby = complete   
    
    lat = galv_clusters_nan.lat[idx]
    long = galv_clusters_nan.long[idx]
    nearby['euc_diff'] = ((nearby['lats']-lat)**2 + (nearby['longs']-long)**2)**0.5
    nearby = complete_copy.nsmallest(20, ['euc_diff'])
    nearby = nearby.reset_index()
    
    #create a list to store distances
    distances = []
    
    coord = str(galv_clusters_nan['long'][idx]) + "," + str(galv_clusters_nan['lat'][idx])
    for i in range(len(nearby)):
        coord = coord + ";" + str(nearby['longs'][i]) +  "," + str(nearby['lats'][i])
    url = "https://api.mapbox.com/directions-matrix/v1/mapbox/walking/" +\
            coord + "?sources=0&annotations=distance,duration"
            
    r = requests.get(url, params=({'access_token':token}))
    r =  json.loads(r.content)
        
    # add distances to list of distances
    for d in r['durations'][0][1:]:
        distances.append(d)
    
    # add distances as a column to our copied version of hilo_sites data
    nearby = nearby.assign(Dist = distances)
    # extract the row with the closest distance
    closest = nearby[nearby.Dist == nearby.Dist.min()]

    # add info from that closest row to our hilo_clusters data
    galv_clusters_nan['site_name'][idx] = closest['Name'].values[0]
    galv_clusters_nan['site_location'][idx] = closest['Coordinates'].values[0]
    galv_clusters_nan['site_dist'][idx] = closest['Dist'].values[0]
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
galv_clusters_nan = gpd.GeoDataFrame(galv_clusters_nan, geometry = galv_clusters_nan.site_location)
galv_clusters_nan = galv_clusters_nan.iloc[:,[0,1,2,4,5]]
galv_clusters_nan
# Out:
#          lat       long                      site_name  site_dist  \
# 0  29.339165 -94.790654         Galveston Naval Museum      140.3
# 1  29.245908 -94.917369              3rd Coast Company      973.1
# 2  29.228554 -94.922662           The Kislyuk Retreat.      851.3
# 3  29.153089 -95.030006                    Sunset Cove      484.0
# 4  29.225714 -94.940945  Laffite's Cove Nature Society      875.3
# 5  29.257354 -94.896649                Sweetwater Cove      371.6
# 6  29.341015 -94.810515                    Pelican Cut        0.0
#
#                      geometry
# 0  POINT (-94.77940 29.33448)
# 1  POINT (-94.90493 29.23666)
# 2  POINT (-94.91741 29.22441)
# 3  POINT (-95.03115 29.14769)
# 4  POINT (-94.93444 29.21761)
# 5  POINT (-94.89778 29.26201)
# 6  POINT (-94.81952 29.34827)

# %%
galv_clusters = galv_clusters[galv_clusters["geometry"]!=None]
galv_clusters
# Out:
#           lat       long                                          site_name  \
# 0   29.201904 -94.944011                             Overkill Guide Service
# 1   29.298048 -94.819682                          Dr. Abbey B. Berenson, MD
# 2   29.131075 -95.061183                                     Pepper Pavilon
# 3   29.264259 -94.877844                               Big M’s Lawn Service
# 5   29.264176 -94.840561                                 Weis Middle School
# 7   29.170826 -95.001971                                 Next Residence LLC
# 8   29.106732 -95.096759                                            7 Palms
# 9   29.287440 -94.801409                           Frazier Painting Company
# 10  29.332274 -94.736772              Galveston Island Horse and Pony Rides
# 11  29.233650 -94.891720  Beachside Village Information Center-Beachside...
# 12  29.312660 -94.769572                  Alcohol Drug Abuse Women's Center
# 13  29.279759 -94.828787                                  Gonzalez Trucking
# 15  29.304436 -94.791288                                      Bob's Grocery
# 17  29.285201 -94.868839                        Galveston County Daily News
# 18  29.246775 -94.871383                      Haney & Associates Appraisers
# 19  29.145756 -95.038735                           Southern Tide Golf Carts
# 20  29.268382 -94.858152                              Galveston Helicopters
# 21  29.287431 -94.821090                             New World Builders LLC
# 22  29.326497 -94.770963       US Army Corps of Engineers - Jadwin Building
# 24  29.298847 -94.782868                                     Ben Roeder Law
# 25  29.125202 -95.070999                                   Seahorse Landing
# 26  29.181627 -94.982618                              Arney’s Bayside Grill
# 27  29.302161 -94.802271        City of Galveston - 30th St Pumping Station
# 28  29.276607 -94.816672                             Hummingbird Landscapes
# 29  29.216310 -94.932354                      Laffite's Cove Nature Society
# 30  29.293601 -94.830978                              Galveston County Jail
# 32  29.224796 -94.906773             Galveston Wholesale Building Materials
# 33  29.289993 -94.857185                           McNatt Contracting, Inc.
# 34  29.095100 -95.108745                                Beach & Bay Getaway
# 35  29.141136 -95.045948                                   Bayside Bungalow
# 36  29.272848 -94.823873  Building, Finish , trim, home repair.. small e...
# 37  29.241487 -94.881977                              Stella Mare RV Resort
# 38  29.237946 -94.904602                         Dr. Maximus M. nkechi, DDS
# 39  29.320108 -94.795390                             JJ'S AUTOMOTIVE REPAIR
# 40  29.201156 -94.965332                        Galveston Island State Park
# 41  29.321137 -94.813297                                         The Galley
# 42  29.207339 -94.934351             Heritage Coastal Vacation Rentals, LLC
# 43  29.215773 -94.918006                Bermuda Beach Improvement Committee
# 44  29.174613 -94.993738                             Texas Campgrounds Club
# 45  29.292930 -94.810792                             Yellow Door Beach Home
# 47  29.268775 -94.831711                   Bank of America ATM (Drive-thru)
# 48  29.114952 -95.087347                                    Laguna San Luis
# 49  29.290873 -94.840267                                      Target Mobile
# 50  29.135951 -95.055539                           Seaside Home Design, LLC
# 51  29.274750 -94.840045                           Parker Elementary School
# 52  29.292860 -94.792756                        The Villa Bed and Breakfast
# 53  29.323648 -94.749938                                         East Beach
# 54  29.308849 -94.778737                              UTMB Parking Garage 3
# 55  29.282033 -94.809318                                         Immaculate
# 56  29.207109 -94.950757                     Blue Bay Vista Vacation Rental
# 57  29.257403 -94.850385                                         Roll-N-Bar
# 58  29.257778 -94.869862                                         Sugar Bean
# 59  29.163103 -95.014353           Sales Center at Galveston Seaside Resort
#
#     site_dist                    geometry
# 0         7.8  POINT (-94.94361 29.20196)
# 1       158.6  POINT (-94.82179 29.29729)
# 2       362.3  POINT (-95.06104 29.13331)
# 3       202.1  POINT (-94.87802 29.26680)
# 5      1183.8  POINT (-94.83880 29.26502)
# 7        36.7  POINT (-95.00167 29.17158)
# 8       201.5  POINT (-95.09597 29.10564)
# 9        26.0  POINT (-94.80136 29.28711)
# 10       53.5  POINT (-94.73449 29.33362)
# 11       98.4  POINT (-94.89144 29.23305)
# 12      108.2  POINT (-94.76927 29.31355)
# 13       91.8  POINT (-94.82909 29.28017)
# 15       11.1  POINT (-94.79123 29.30477)
# 17      210.8  POINT (-94.86598 29.28484)
# 18       65.5  POINT (-94.87002 29.24609)
# 19      739.9  POINT (-95.03921 29.14245)
# 20       14.2  POINT (-94.85535 29.26819)
# 21      109.1  POINT (-94.82102 29.28878)
# 22      467.3  POINT (-94.77226 29.33009)
# 24       65.0  POINT (-94.78292 29.29968)
# 25      226.8  POINT (-95.07057 29.12441)
# 26      162.3  POINT (-94.98233 29.18009)
# 27      111.8  POINT (-94.80204 29.30176)
# 28      191.7  POINT (-94.81538 29.27803)
# 29      420.0  POINT (-94.93444 29.21761)
# 30      172.4  POINT (-94.83140 29.29297)
# 32      127.5  POINT (-94.90660 29.22305)
# 33       98.1  POINT (-94.85925 29.28984)
# 34       88.3  POINT (-95.10984 29.09500)
# 35       86.1  POINT (-95.04603 29.14055)
# 36      137.1  POINT (-94.82348 29.27112)
# 37      103.7  POINT (-94.88161 29.24052)
# 38      115.7  POINT (-94.90514 29.23831)
# 39      219.5  POINT (-94.79784 29.32269)
# 40      314.2  POINT (-94.96615 29.20331)
# 41      202.1  POINT (-94.81503 29.31847)
# 42      186.7  POINT (-94.93610 29.20792)
# 43      446.0  POINT (-94.91673 29.21567)
# 44      231.7  POINT (-94.99151 29.17131)
# 45      104.9  POINT (-94.81121 29.29190)
# 47       90.6  POINT (-94.83025 29.26857)
# 48      170.0  POINT (-95.08820 29.11323)
# 49        0.3  POINT (-94.84044 29.29116)
# 50      164.3  POINT (-95.05460 29.13787)
# 51      126.5  POINT (-94.83902 29.27342)
# 52       72.5  POINT (-94.79223 29.29247)
# 53      684.7  POINT (-94.74760 29.32122)
# 54       35.9  POINT (-94.77837 29.30917)
# 55      101.1  POINT (-94.80950 29.28129)
# 56      153.2  POINT (-94.94991 29.20707)
# 57      260.7  POINT (-94.84815 29.25643)
# 58      300.0  POINT (-94.87042 29.26103)
# 59      359.3  POINT (-95.01349 29.16255)

# %%
galv_clusters = gpd.GeoDataFrame(galv_clusters, geometry = galv_clusters.site_location)
galv_clusters = galv_clusters.iloc[:,[0,1,2,4,5]]

# %%
galv_clusters_complete = pd.concat([galv_clusters_nan,galv_clusters]).reset_index()
galv_clusters_complete = gpd.GeoDataFrame(galv_clusters_complete, geometry = galv_clusters_complete.geometry)
galv_clusters_complete
# Out:
#     index        lat       long  \
# 0       0  29.339165 -94.790654
# 1       1  29.245908 -94.917369
# 2       2  29.228554 -94.922662
# 3       3  29.153089 -95.030006
# 4       4  29.225714 -94.940945
# 5       5  29.257354 -94.896649
# 6       6  29.341015 -94.810515
# 7       0  29.201904 -94.944011
# 8       1  29.298048 -94.819682
# 9       2  29.131075 -95.061183
# 10      3  29.264259 -94.877844
# 11      5  29.264176 -94.840561
# 12      7  29.170826 -95.001971
# 13      8  29.106732 -95.096759
# 14      9  29.287440 -94.801409
# 15     10  29.332274 -94.736772
# 16     11  29.233650 -94.891720
# 17     12  29.312660 -94.769572
# 18     13  29.279759 -94.828787
# 19     15  29.304436 -94.791288
# 20     17  29.285201 -94.868839
# 21     18  29.246775 -94.871383
# 22     19  29.145756 -95.038735
# 23     20  29.268382 -94.858152
# 24     21  29.287431 -94.821090
# 25     22  29.326497 -94.770963
# 26     24  29.298847 -94.782868
# 27     25  29.125202 -95.070999
# 28     26  29.181627 -94.982618
# 29     27  29.302161 -94.802271
# 30     28  29.276607 -94.816672
# 31     29  29.216310 -94.932354
# 32     30  29.293601 -94.830978
# 33     32  29.224796 -94.906773
# 34     33  29.289993 -94.857185
# 35     34  29.095100 -95.108745
# 36     35  29.141136 -95.045948
# 37     36  29.272848 -94.823873
# 38     37  29.241487 -94.881977
# 39     38  29.237946 -94.904602
# 40     39  29.320108 -94.795390
# 41     40  29.201156 -94.965332
# 42     41  29.321137 -94.813297
# 43     42  29.207339 -94.934351
# 44     43  29.215773 -94.918006
# 45     44  29.174613 -94.993738
# 46     45  29.292930 -94.810792
# 47     47  29.268775 -94.831711
# 48     48  29.114952 -95.087347
# 49     49  29.290873 -94.840267
# 50     50  29.135951 -95.055539
# 51     51  29.274750 -94.840045
# 52     52  29.292860 -94.792756
# 53     53  29.323648 -94.749938
# 54     54  29.308849 -94.778737
# 55     55  29.282033 -94.809318
# 56     56  29.207109 -94.950757
# 57     57  29.257403 -94.850385
# 58     58  29.257778 -94.869862
# 59     59  29.163103 -95.014353
#
#                                             site_name  site_dist  \
# 0                              Galveston Naval Museum      140.3
# 1                                   3rd Coast Company      973.1
# 2                                The Kislyuk Retreat.      851.3
# 3                                         Sunset Cove      484.0
# 4                       Laffite's Cove Nature Society      875.3
# 5                                     Sweetwater Cove      371.6
# 6                                         Pelican Cut        0.0
# 7                              Overkill Guide Service        7.8
# 8                           Dr. Abbey B. Berenson, MD      158.6
# 9                                      Pepper Pavilon      362.3
# 10                               Big M’s Lawn Service      202.1
# 11                                 Weis Middle School     1183.8
# 12                                 Next Residence LLC       36.7
# 13                                            7 Palms      201.5
# 14                           Frazier Painting Company       26.0
# 15              Galveston Island Horse and Pony Rides       53.5
# 16  Beachside Village Information Center-Beachside...       98.4
# 17                  Alcohol Drug Abuse Women's Center      108.2
# 18                                  Gonzalez Trucking       91.8
# 19                                      Bob's Grocery       11.1
# 20                        Galveston County Daily News      210.8
# 21                      Haney & Associates Appraisers       65.5
# 22                           Southern Tide Golf Carts      739.9
# 23                              Galveston Helicopters       14.2
# 24                             New World Builders LLC      109.1
# 25       US Army Corps of Engineers - Jadwin Building      467.3
# 26                                     Ben Roeder Law       65.0
# 27                                   Seahorse Landing      226.8
# 28                              Arney’s Bayside Grill      162.3
# 29        City of Galveston - 30th St Pumping Station      111.8
# 30                             Hummingbird Landscapes      191.7
# 31                      Laffite's Cove Nature Society      420.0
# 32                              Galveston County Jail      172.4
# 33             Galveston Wholesale Building Materials      127.5
# 34                           McNatt Contracting, Inc.       98.1
# 35                                Beach & Bay Getaway       88.3
# 36                                   Bayside Bungalow       86.1
# 37  Building, Finish , trim, home repair.. small e...      137.1
# 38                              Stella Mare RV Resort      103.7
# 39                         Dr. Maximus M. nkechi, DDS      115.7
# 40                             JJ'S AUTOMOTIVE REPAIR      219.5
# 41                        Galveston Island State Park      314.2
# 42                                         The Galley      202.1
# 43             Heritage Coastal Vacation Rentals, LLC      186.7
# 44                Bermuda Beach Improvement Committee      446.0
# 45                             Texas Campgrounds Club      231.7
# 46                             Yellow Door Beach Home      104.9
# 47                   Bank of America ATM (Drive-thru)       90.6
# 48                                    Laguna San Luis      170.0
# 49                                      Target Mobile        0.3
# 50                           Seaside Home Design, LLC      164.3
# 51                           Parker Elementary School      126.5
# 52                        The Villa Bed and Breakfast       72.5
# 53                                         East Beach      684.7
# 54                              UTMB Parking Garage 3       35.9
# 55                                         Immaculate      101.1
# 56                     Blue Bay Vista Vacation Rental      153.2
# 57                                         Roll-N-Bar      260.7
# 58                                         Sugar Bean      300.0
# 59           Sales Center at Galveston Seaside Resort      359.3
#
#                       geometry
# 0   POINT (-94.77940 29.33448)
# 1   POINT (-94.90493 29.23666)
# 2   POINT (-94.91741 29.22441)
# 3   POINT (-95.03115 29.14769)
# 4   POINT (-94.93444 29.21761)
# 5   POINT (-94.89778 29.26201)
# 6   POINT (-94.81952 29.34827)
# 7   POINT (-94.94361 29.20196)
# 8   POINT (-94.82179 29.29729)
# 9   POINT (-95.06104 29.13331)
# 10  POINT (-94.87802 29.26680)
# 11  POINT (-94.83880 29.26502)
# 12  POINT (-95.00167 29.17158)
# 13  POINT (-95.09597 29.10564)
# 14  POINT (-94.80136 29.28711)
# 15  POINT (-94.73449 29.33362)
# 16  POINT (-94.89144 29.23305)
# 17  POINT (-94.76927 29.31355)
# 18  POINT (-94.82909 29.28017)
# 19  POINT (-94.79123 29.30477)
# 20  POINT (-94.86598 29.28484)
# 21  POINT (-94.87002 29.24609)
# 22  POINT (-95.03921 29.14245)
# 23  POINT (-94.85535 29.26819)
# 24  POINT (-94.82102 29.28878)
# 25  POINT (-94.77226 29.33009)
# 26  POINT (-94.78292 29.29968)
# 27  POINT (-95.07057 29.12441)
# 28  POINT (-94.98233 29.18009)
# 29  POINT (-94.80204 29.30176)
# 30  POINT (-94.81538 29.27803)
# 31  POINT (-94.93444 29.21761)
# 32  POINT (-94.83140 29.29297)
# 33  POINT (-94.90660 29.22305)
# 34  POINT (-94.85925 29.28984)
# 35  POINT (-95.10984 29.09500)
# 36  POINT (-95.04603 29.14055)
# 37  POINT (-94.82348 29.27112)
# 38  POINT (-94.88161 29.24052)
# 39  POINT (-94.90514 29.23831)
# 40  POINT (-94.79784 29.32269)
# 41  POINT (-94.96615 29.20331)
# 42  POINT (-94.81503 29.31847)
# 43  POINT (-94.93610 29.20792)
# 44  POINT (-94.91673 29.21567)
# 45  POINT (-94.99151 29.17131)
# 46  POINT (-94.81121 29.29190)
# 47  POINT (-94.83025 29.26857)
# 48  POINT (-95.08820 29.11323)
# 49  POINT (-94.84044 29.29116)
# 50  POINT (-95.05460 29.13787)
# 51  POINT (-94.83902 29.27342)
# 52  POINT (-94.79223 29.29247)
# 53  POINT (-94.74760 29.32122)
# 54  POINT (-94.77837 29.30917)
# 55  POINT (-94.80950 29.28129)
# 56  POINT (-94.94991 29.20707)
# 57  POINT (-94.84815 29.25643)
# 58  POINT (-94.87042 29.26103)
# 59  POINT (-95.01349 29.16255)

# %%
galv_clusters_complete = galv_clusters_complete.iloc[:,[1,2,3,4,5]]

# %%
# save as a geojson file for the ease of mapping
galv_clusters_complete.to_file('galv_cluster_collection_sites_60.geojson', driver = 'GeoJSON')

# %%
buffer = galv_clusters_complete.buffer(0.004)
galv_copy = galv_clusters_complete[:]
galv_copy["geometry"] = buffer
galv_copy.to_file("galv_cluster_collection_sites_buffer_60.geojson",driver="GeoJSON")

# %%
galv_copy
# Out:
#           lat       long                                          site_name  \
# 0   29.339165 -94.790654                             Galveston Naval Museum
# 1   29.245908 -94.917369                                  3rd Coast Company
# 2   29.228554 -94.922662                               The Kislyuk Retreat.
# 3   29.153089 -95.030006                                        Sunset Cove
# 4   29.225714 -94.940945                      Laffite's Cove Nature Society
# 5   29.257354 -94.896649                                    Sweetwater Cove
# 6   29.341015 -94.810515                                        Pelican Cut
# 7   29.201904 -94.944011                             Overkill Guide Service
# 8   29.298048 -94.819682                          Dr. Abbey B. Berenson, MD
# 9   29.131075 -95.061183                                     Pepper Pavilon
# 10  29.264259 -94.877844                               Big M’s Lawn Service
# 11  29.264176 -94.840561                                 Weis Middle School
# 12  29.170826 -95.001971                                 Next Residence LLC
# 13  29.106732 -95.096759                                            7 Palms
# 14  29.287440 -94.801409                           Frazier Painting Company
# 15  29.332274 -94.736772              Galveston Island Horse and Pony Rides
# 16  29.233650 -94.891720  Beachside Village Information Center-Beachside...
# 17  29.312660 -94.769572                  Alcohol Drug Abuse Women's Center
# 18  29.279759 -94.828787                                  Gonzalez Trucking
# 19  29.304436 -94.791288                                      Bob's Grocery
# 20  29.285201 -94.868839                        Galveston County Daily News
# 21  29.246775 -94.871383                      Haney & Associates Appraisers
# 22  29.145756 -95.038735                           Southern Tide Golf Carts
# 23  29.268382 -94.858152                              Galveston Helicopters
# 24  29.287431 -94.821090                             New World Builders LLC
# 25  29.326497 -94.770963       US Army Corps of Engineers - Jadwin Building
# 26  29.298847 -94.782868                                     Ben Roeder Law
# 27  29.125202 -95.070999                                   Seahorse Landing
# 28  29.181627 -94.982618                              Arney’s Bayside Grill
# 29  29.302161 -94.802271        City of Galveston - 30th St Pumping Station
# 30  29.276607 -94.816672                             Hummingbird Landscapes
# 31  29.216310 -94.932354                      Laffite's Cove Nature Society
# 32  29.293601 -94.830978                              Galveston County Jail
# 33  29.224796 -94.906773             Galveston Wholesale Building Materials
# 34  29.289993 -94.857185                           McNatt Contracting, Inc.
# 35  29.095100 -95.108745                                Beach & Bay Getaway
# 36  29.141136 -95.045948                                   Bayside Bungalow
# 37  29.272848 -94.823873  Building, Finish , trim, home repair.. small e...
# 38  29.241487 -94.881977                              Stella Mare RV Resort
# 39  29.237946 -94.904602                         Dr. Maximus M. nkechi, DDS
# 40  29.320108 -94.795390                             JJ'S AUTOMOTIVE REPAIR
# 41  29.201156 -94.965332                        Galveston Island State Park
# 42  29.321137 -94.813297                                         The Galley
# 43  29.207339 -94.934351             Heritage Coastal Vacation Rentals, LLC
# 44  29.215773 -94.918006                Bermuda Beach Improvement Committee
# 45  29.174613 -94.993738                             Texas Campgrounds Club
# 46  29.292930 -94.810792                             Yellow Door Beach Home
# 47  29.268775 -94.831711                   Bank of America ATM (Drive-thru)
# 48  29.114952 -95.087347                                    Laguna San Luis
# 49  29.290873 -94.840267                                      Target Mobile
# 50  29.135951 -95.055539                           Seaside Home Design, LLC
# 51  29.274750 -94.840045                           Parker Elementary School
# 52  29.292860 -94.792756                        The Villa Bed and Breakfast
# 53  29.323648 -94.749938                                         East Beach
# 54  29.308849 -94.778737                              UTMB Parking Garage 3
# 55  29.282033 -94.809318                                         Immaculate
# 56  29.207109 -94.950757                     Blue Bay Vista Vacation Rental
# 57  29.257403 -94.850385                                         Roll-N-Bar
# 58  29.257778 -94.869862                                         Sugar Bean
# 59  29.163103 -95.014353           Sales Center at Galveston Seaside Resort
#
#     site_dist                                           geometry
# 0       140.3  POLYGON ((-94.77540 29.33448, -94.77542 29.334...
# 1       973.1  POLYGON ((-94.90093 29.23666, -94.90095 29.236...
# 2       851.3  POLYGON ((-94.91341 29.22441, -94.91343 29.224...
# 3       484.0  POLYGON ((-95.02715 29.14769, -95.02717 29.147...
# 4       875.3  POLYGON ((-94.93044 29.21761, -94.93046 29.217...
# 5       371.6  POLYGON ((-94.89378 29.26201, -94.89380 29.261...
# 6         0.0  POLYGON ((-94.81552 29.34827, -94.81554 29.347...
# 7         7.8  POLYGON ((-94.93961 29.20196, -94.93963 29.201...
# 8       158.6  POLYGON ((-94.81779 29.29729, -94.81780 29.296...
# 9       362.3  POLYGON ((-95.05704 29.13331, -95.05706 29.132...
# 10      202.1  POLYGON ((-94.87402 29.26680, -94.87403 29.266...
# 11     1183.8  POLYGON ((-94.83480 29.26502, -94.83482 29.264...
# 12       36.7  POLYGON ((-94.99767 29.17158, -94.99769 29.171...
# 13      201.5  POLYGON ((-95.09197 29.10564, -95.09199 29.105...
# 14       26.0  POLYGON ((-94.79736 29.28711, -94.79738 29.286...
# 15       53.5  POLYGON ((-94.73049 29.33362, -94.73051 29.333...
# 16       98.4  POLYGON ((-94.88744 29.23305, -94.88746 29.232...
# 17      108.2  POLYGON ((-94.76527 29.31355, -94.76529 29.313...
# 18       91.8  POLYGON ((-94.82509 29.28017, -94.82511 29.279...
# 19       11.1  POLYGON ((-94.78723 29.30477, -94.78725 29.304...
# 20      210.8  POLYGON ((-94.86198 29.28484, -94.86200 29.284...
# 21       65.5  POLYGON ((-94.86602 29.24609, -94.86604 29.245...
# 22      739.9  POLYGON ((-95.03521 29.14245, -95.03523 29.142...
# 23       14.2  POLYGON ((-94.85135 29.26819, -94.85136 29.267...
# 24      109.1  POLYGON ((-94.81702 29.28878, -94.81704 29.288...
# 25      467.3  POLYGON ((-94.76826 29.33009, -94.76828 29.329...
# 26       65.0  POLYGON ((-94.77892 29.29968, -94.77894 29.299...
# 27      226.8  POLYGON ((-95.06657 29.12441, -95.06659 29.124...
# 28      162.3  POLYGON ((-94.97833 29.18009, -94.97835 29.179...
# 29      111.8  POLYGON ((-94.79804 29.30176, -94.79806 29.301...
# 30      191.7  POLYGON ((-94.81138 29.27803, -94.81140 29.277...
# 31      420.0  POLYGON ((-94.93044 29.21761, -94.93046 29.217...
# 32      172.4  POLYGON ((-94.82740 29.29297, -94.82742 29.292...
# 33      127.5  POLYGON ((-94.90260 29.22305, -94.90262 29.222...
# 34       98.1  POLYGON ((-94.85525 29.28984, -94.85527 29.289...
# 35       88.3  POLYGON ((-95.10584 29.09500, -95.10586 29.094...
# 36       86.1  POLYGON ((-95.04203 29.14055, -95.04205 29.140...
# 37      137.1  POLYGON ((-94.81948 29.27112, -94.81950 29.270...
# 38      103.7  POLYGON ((-94.87761 29.24052, -94.87763 29.240...
# 39      115.7  POLYGON ((-94.90114 29.23831, -94.90116 29.237...
# 40      219.5  POLYGON ((-94.79384 29.32269, -94.79386 29.322...
# 41      314.2  POLYGON ((-94.96215 29.20331, -94.96217 29.202...
# 42      202.1  POLYGON ((-94.81103 29.31847, -94.81105 29.318...
# 43      186.7  POLYGON ((-94.93210 29.20792, -94.93212 29.207...
# 44      446.0  POLYGON ((-94.91273 29.21567, -94.91275 29.215...
# 45      231.7  POLYGON ((-94.98751 29.17131, -94.98753 29.170...
# 46      104.9  POLYGON ((-94.80721 29.29190, -94.80723 29.291...
# 47       90.6  POLYGON ((-94.82625 29.26857, -94.82627 29.268...
# 48      170.0  POLYGON ((-95.08420 29.11323, -95.08422 29.112...
# 49        0.3  POLYGON ((-94.83644 29.29116, -94.83646 29.290...
# 50      164.3  POLYGON ((-95.05060 29.13787, -95.05061 29.137...
# 51      126.5  POLYGON ((-94.83502 29.27342, -94.83504 29.273...
# 52       72.5  POLYGON ((-94.78823 29.29247, -94.78825 29.292...
# 53      684.7  POLYGON ((-94.74360 29.32122, -94.74362 29.320...
# 54       35.9  POLYGON ((-94.77437 29.30917, -94.77439 29.308...
# 55      101.1  POLYGON ((-94.80550 29.28129, -94.80552 29.280...
# 56      153.2  POLYGON ((-94.94591 29.20707, -94.94593 29.206...
# 57      260.7  POLYGON ((-94.84415 29.25643, -94.84416 29.256...
# 58      300.0  POLYGON ((-94.86642 29.26103, -94.86644 29.260...
# 59      359.3  POLYGON ((-95.00949 29.16255, -95.00951 29.162...
