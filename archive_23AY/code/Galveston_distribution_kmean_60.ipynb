# %% [markdown]
# #### In this jupyter notebook, I made 80 clusters for all local business with the convenience score calculated by Ziyu as weight
# #### And I created coverage area based on the cluster centers I generated

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import csv
import geopandas as gpd

# %%
# Import dataset that contains convenience score - the weight column (Ziyu made the file)
galveston_business = pd.read_csv("../data/galv_dist_detail.csv")
galveston_business
# Out:
#      Unnamed: 0                                            Name  \
# 0             0  Moody Gardens Hotel, Spa and Convention Center
# 1             1                                 Rainforest Cafe
# 2             2                 Landry's Prime Seafood & Steaks
# 3             3               Number 13 Prime Steak and Seafood
# 4             4                               Fisherman's Wharf
# ..          ...                                             ...
# 408         408                               Chevron Galveston
# 409         409                                 Circle K/Valero
# 410         410                              Moody State School
# 411         411                                           Shell
# 412         412                Tipsy Turtle Seaside Bar & Grill
#
#                                                Address  \
# 0                          7 Hope Boulevard, Galveston
# 1                    5310 Seawall Boulevard, Galveston
# 2                    5310 Seawall Boulevard, Galveston
# 3                      7809 Broadway Street, Galveston
# 4                     2200 Harborside Drive, Galveston
# ..                                                 ...
# 408                   601 Broadway Avenue J, Galveston
# 409                   628 Broadway Avenue J, Galveston
# 410                                          Galveston
# 411                  5027 Broadway Avenue J, Galveston
# 412  11745 Termini-San Luis Pass Rd Galveston, TX 7...
#
#                                Coordinates        Lat       Long  fast_food  \
# 0    POINT (-94.85032249999999 29.2734603)  29.273460 -94.850323          0
# 1           POINT (-94.8202072 29.2707531)  29.270753 -94.820207          0
# 2           POINT (-94.8202317 29.2707352)  29.270735 -94.820232          0
# 3    POINT (-94.85753559999999 29.2850878)  29.285088 -94.857536          0
# 4           POINT (-94.7936367 29.3089314)  29.308931 -94.793637          0
# ..                                     ...        ...        ...        ...
# 408         POINT (-94.7731482 29.3045091)  29.304509 -94.773148          0
# 409  POINT (-94.7735891 29.30539089999999)  29.305391 -94.773589          0
# 410         POINT (-94.8665867 29.2819039)  29.281904 -94.866587          0
# 411         POINT (-94.8237905 29.2915092)  29.291509 -94.823791          0
# 412           POINT (-94.896047 29.227571)  29.227571 -94.896047          0
#
#      user_ratings_total  bakery  cafe  meal_delivery  meal_takeaway  \
# 0              0.000000       0     1              1              1
# 1              0.449872       0     1              1              1
# 2              0.238552       0     1              1              1
# 3              0.063072       0     1              1              1
# 4              0.342838       0     1              1              1
# ..                  ...     ...   ...            ...            ...
# 408            0.001221       0     1              1              1
# 409            0.000000       0     1              1              1
# 410            0.000000       0     1              1              1
# 411            0.001404       0     1              1              1
# 412            0.000000       0     1              1              1
#
#      restaurant  food  hours_open     weight
# 0             0     0    0.360119   7.220238
# 1             1     1    0.428571  12.307015
# 2             1     1    0.428571  12.095695
# 3             1     1    0.273810  11.610691
# 4             1     1    0.360119  12.063076
# ..          ...   ...         ...        ...
# 408           0     1    1.000000  11.501221
# 409           0     0    0.360119   7.220238
# 410           0     0    0.360119   7.220238
# 411           0     1    0.360119  10.221642
# 412           0     0    0.360119   7.220238
#
# [413 rows x 16 columns]

# %%
# Create an elbow plot to help us determine k
K_clusters = range(1,100)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = galveston_business[['Lat']]
X_axis = galveston_business[['Long']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
# Perform kmean with 80 clusters with weight (convenience score)
kmeans = KMeans(n_clusters = 60, init ='k-means++')
kmeans.fit(galveston_business[["Lat","Long"]], sample_weight = galveston_business["weight"]) # Compute k-means clustering.
galveston_business['cluster_label'] = kmeans.fit_predict(galveston_business[["Lat","Long"]], sample_weight = galveston_business["weight"])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(galveston_business[["Lat","Long"]], sample_weight = galveston_business["weight"]) # Labels of each point
galveston_business.head(10)
# Out:
#    Unnamed: 0                                            Name  \
# 0           0  Moody Gardens Hotel, Spa and Convention Center
# 1           1                                 Rainforest Cafe
# 2           2                 Landry's Prime Seafood & Steaks
# 3           3               Number 13 Prime Steak and Seafood
# 4           4                               Fisherman's Wharf
# 5           5                                        The Spot
# 6           6                                  Shrimp N Stuff
# 7           7                     Willie G's Seafood & Steaks
# 8           8                    Nick's Kitchen and Beach Bar
# 9           9                                         Gaido's
#
#                              Address                            Coordinates  \
# 0        7 Hope Boulevard, Galveston  POINT (-94.85032249999999 29.2734603)
# 1  5310 Seawall Boulevard, Galveston         POINT (-94.8202072 29.2707531)
# 2  5310 Seawall Boulevard, Galveston         POINT (-94.8202317 29.2707352)
# 3    7809 Broadway Street, Galveston  POINT (-94.85753559999999 29.2850878)
# 4   2200 Harborside Drive, Galveston         POINT (-94.7936367 29.3089314)
# 5  3204 Seawall Boulevard, Galveston         POINT (-94.7980051 29.2836047)
# 6           3901 Avenue O, Galveston         POINT (-94.8084087 29.2888755)
# 7   2100 Harborside Drive, Galveston   POINT (-94.79280299999999 29.309303)
# 8  3802 Seawall Boulevard, Galveston         POINT (-94.8040028 29.2797917)
# 9  3828 Seawall Boulevard, Galveston  POINT (-94.80449999999999 29.2796255)
#
#          Lat       Long  fast_food  user_ratings_total  bakery  cafe  \
# 0  29.273460 -94.850323          0            0.000000       0     1
# 1  29.270753 -94.820207          0            0.449872       0     1
# 2  29.270735 -94.820232          0            0.238552       0     1
# 3  29.285088 -94.857536          0            0.063072       0     1
# 4  29.308931 -94.793637          0            0.342838       0     1
# 5  29.283605 -94.798005          0            0.771767       0     1
# 6  29.288875 -94.808409          0            0.305349       0     1
# 7  29.309303 -94.792803          0            0.182440       0     1
# 8  29.279792 -94.804003          0            0.215899       0     1
# 9  29.279626 -94.804500          0            0.331664       0     1
#
#    meal_delivery  meal_takeaway  restaurant  food  hours_open     weight  \
# 0              1              1           0     0    0.360119   7.220238
# 1              1              1           1     1    0.428571  12.307015
# 2              1              1           1     1    0.428571  12.095695
# 3              1              1           1     1    0.273810  11.610691
# 4              1              1           1     1    0.360119  12.063076
# 5              1              1           1     1    0.470238  12.712243
# 6              1              1           1     1    0.360119  12.025587
# 7              1              1           1     1    0.360119  11.902678
# 8              1              1           1     1    0.428571  12.073042
# 9              1              1           1     1    0.360119  12.051903
#
#    cluster_label
# 0             15
# 1             27
# 2             27
# 3             18
# 4             39
# 5             51
# 6             50
# 7             39
# 8             41
# 9             41

# %%
# Create geodataframe for the dataset
galveston_business_gdf = gpd.GeoDataFrame(
    galveston_business, geometry=gpd.points_from_xy(galveston_business.Long, galveston_business.Lat, crs='epsg:4326'),crs=4326)

# %%
# Transform the 60 cluster centers to geodataframe for geojson generating
center_df = pd.DataFrame(centers, columns = ['lat','long'])
center_gdf = gpd.GeoDataFrame(
    center_df, geometry=gpd.points_from_xy(center_df.long, center_df.lat, crs='epsg:4326'),crs=4326) 
center_gdf
# Out:
#           lat       long                    geometry
# 0   29.315936 -94.817366  POINT (-94.81737 29.31594)
# 1   29.182137 -94.974689  POINT (-94.97469 29.18214)
# 2   29.875160 -95.770610  POINT (-95.77061 29.87516)
# 3   29.274335 -94.832399  POINT (-94.83240 29.27433)
# 4   29.501650 -95.056980  POINT (-95.05698 29.50165)
# 5   29.300882 -94.776003  POINT (-94.77600 29.30088)
# 6   28.966447 -95.364985  POINT (-95.36499 28.96645)
# 7   29.245418 -94.868036  POINT (-94.86804 29.24542)
# 8   29.287856 -94.811994  POINT (-94.81199 29.28786)
# 9   29.207288 -94.935700  POINT (-94.93570 29.20729)
# 10  29.301945 -94.904062  POINT (-94.90406 29.30194)
# 11  29.298131 -94.795149  POINT (-94.79515 29.29813)
# 12  29.143291 -95.043765  POINT (-95.04376 29.14329)
# 13  29.540070 -95.124550  POINT (-95.12455 29.54007)
# 14  29.289836 -94.829662  POINT (-94.82966 29.28984)
# 15  29.272263 -94.851465  POINT (-94.85147 29.27226)
# 16  29.270825 -94.829121  POINT (-94.82912 29.27082)
# 17  29.227576 -94.896449  POINT (-94.89645 29.22758)
# 18  29.285980 -94.861802  POINT (-94.86180 29.28598)
# 19  29.275668 -94.811530  POINT (-94.81153 29.27567)
# 20  29.259070 -94.849406  POINT (-94.84941 29.25907)
# 21  29.205181 -94.948668  POINT (-94.94867 29.20518)
# 22  29.306635 -94.790943  POINT (-94.79094 29.30664)
# 23  29.287287 -94.792430  POINT (-94.79243 29.28729)
# 24  29.276687 -94.830893  POINT (-94.83089 29.27669)
# 25  29.295656 -94.809578  POINT (-94.80958 29.29566)
# 26  29.288442 -94.838210  POINT (-94.83821 29.28844)
# 27  29.272500 -94.817731  POINT (-94.81773 29.27250)
# 28  29.319577 -94.750220  POINT (-94.75022 29.31958)
# 29  29.306137 -94.771992  POINT (-94.77199 29.30614)
# 30  29.262066 -94.870091  POINT (-94.87009 29.26207)
# 31  29.293180 -94.786669  POINT (-94.78667 29.29318)
# 32  29.252012 -94.854302  POINT (-94.85430 29.25201)
# 33  29.220244 -94.964311  POINT (-94.96431 29.22024)
# 34  29.233848 -94.882358  POINT (-94.88236 29.23385)
# 35  29.264019 -94.832566  POINT (-94.83257 29.26402)
# 36  29.297780 -94.782180  POINT (-94.78218 29.29778)
# 37  29.291072 -94.824213  POINT (-94.82421 29.29107)
# 38  29.218877 -94.909795  POINT (-94.90980 29.21888)
# 39  29.306759 -94.794319  POINT (-94.79432 29.30676)
# 40  29.176107 -94.984617  POINT (-94.98462 29.17611)
# 41  29.279709 -94.804251  POINT (-94.80425 29.27971)
# 42  29.306474 -94.782352  POINT (-94.78235 29.30647)
# 43  29.281208 -94.812478  POINT (-94.81248 29.28121)
# 44  29.221928 -94.932671  POINT (-94.93267 29.22193)
# 45  29.280000 -94.833352  POINT (-94.83335 29.28000)
# 46  29.261533 -94.840307  POINT (-94.84031 29.26153)
# 47  29.293998 -94.816524  POINT (-94.81652 29.29400)
# 48  29.272172 -94.839746  POINT (-94.83975 29.27217)
# 49  29.297667 -94.803507  POINT (-94.80351 29.29767)
# 50  29.290407 -94.808334  POINT (-94.80833 29.29041)
# 51  29.282454 -94.799988  POINT (-94.79999 29.28245)
# 52  29.239562 -94.877620  POINT (-94.87762 29.23956)
# 53  29.194083 -94.954598  POINT (-94.95460 29.19408)
# 54  29.277434 -94.822786  POINT (-94.82279 29.27743)
# 55  29.275643 -94.852451  POINT (-94.85245 29.27564)
# 56  29.267337 -94.826183  POINT (-94.82618 29.26734)
# 57  29.310476 -94.776096  POINT (-94.77610 29.31048)
# 58  29.303889 -94.799198  POINT (-94.79920 29.30389)
# 59  29.300160 -94.789793  POINT (-94.78979 29.30016)

# %%
# Create geodataframe for 60 buffer zone for geojson generating
buffer = center_gdf.buffer(0.004)
center_df_1 = center_df[:]
center_gdf_1 = gpd.GeoDataFrame(
    center_df_1, geometry=buffer,crs=4326)
# Out:
# C:\Users\Charlie Qiu\AppData\Local\Temp\ipykernel_139708\2365887168.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   buffer = center_gdf.buffer(0.004)

# %%
# Provide Visualization for current distribution points
fig, ax = plt.subplots(figsize=(20, 20))
center_gdf_1[(center_gdf_1["lat"]>=29.25) & (center_gdf_1["long"]>=-94.88) & (center_gdf_1["lat"]<=29.4)].plot(ax=ax,color="red")
center_gdf[(center_gdf["lat"]>=29.25) & (center_gdf["long"]>=-94.88) & (center_gdf["lat"]<=29.4)].plot(ax=ax)
galveston_business_gdf[(galveston_business_gdf["Lat"]>=29.25) & (galveston_business_gdf["Long"]>=-94.88) & (galveston_business_gdf["Lat"]<=29.4)].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Extract all the relevant columns
galveston_business_gdf = galveston_business_gdf.loc[:,["Name","Address","Coordinates","Lat","Long","geometry"]]
galveston_business_gdf
# Out:
#                                                Name  \
# 0    Moody Gardens Hotel, Spa and Convention Center
# 1                                   Rainforest Cafe
# 2                   Landry's Prime Seafood & Steaks
# 3                 Number 13 Prime Steak and Seafood
# 4                                 Fisherman's Wharf
# ..                                              ...
# 408                               Chevron Galveston
# 409                                 Circle K/Valero
# 410                              Moody State School
# 411                                           Shell
# 412                Tipsy Turtle Seaside Bar & Grill
#
#                                                Address  \
# 0                          7 Hope Boulevard, Galveston
# 1                    5310 Seawall Boulevard, Galveston
# 2                    5310 Seawall Boulevard, Galveston
# 3                      7809 Broadway Street, Galveston
# 4                     2200 Harborside Drive, Galveston
# ..                                                 ...
# 408                   601 Broadway Avenue J, Galveston
# 409                   628 Broadway Avenue J, Galveston
# 410                                          Galveston
# 411                  5027 Broadway Avenue J, Galveston
# 412  11745 Termini-San Luis Pass Rd Galveston, TX 7...
#
#                                Coordinates        Lat       Long  \
# 0    POINT (-94.85032249999999 29.2734603)  29.273460 -94.850323
# 1           POINT (-94.8202072 29.2707531)  29.270753 -94.820207
# 2           POINT (-94.8202317 29.2707352)  29.270735 -94.820232
# 3    POINT (-94.85753559999999 29.2850878)  29.285088 -94.857536
# 4           POINT (-94.7936367 29.3089314)  29.308931 -94.793637
# ..                                     ...        ...        ...
# 408         POINT (-94.7731482 29.3045091)  29.304509 -94.773148
# 409  POINT (-94.7735891 29.30539089999999)  29.305391 -94.773589
# 410         POINT (-94.8665867 29.2819039)  29.281904 -94.866587
# 411         POINT (-94.8237905 29.2915092)  29.291509 -94.823791
# 412           POINT (-94.896047 29.227571)  29.227571 -94.896047
#
#                        geometry
# 0    POINT (-94.85032 29.27346)
# 1    POINT (-94.82021 29.27075)
# 2    POINT (-94.82023 29.27074)
# 3    POINT (-94.85754 29.28509)
# 4    POINT (-94.79364 29.30893)
# ..                          ...
# 408  POINT (-94.77315 29.30451)
# 409  POINT (-94.77359 29.30539)
# 410  POINT (-94.86659 29.28190)
# 411  POINT (-94.82379 29.29151)
# 412  POINT (-94.89605 29.22757)
#
# [413 rows x 6 columns]

# %%
# Create geojson for Galveston's local business
galveston_business_gdf.to_file("galveston_local_business_60.geojson", driver="GeoJSON")

# %%
# Create geojson for distribution point (cluster center)
center_gdf.to_file("galveston_distribution_centroid_60.geojson", driver="GeoJSON")

# %%
# Create geojson for distribution point's buffer zone (coverage are)
center_gdf_1.to_file("galveston_distribution_buffer_60.geojson",driver="GeoJSON")

# %% [markdown]
# ####  I use QGIS and ArcGIS to finish mapping, the links are in the README file
