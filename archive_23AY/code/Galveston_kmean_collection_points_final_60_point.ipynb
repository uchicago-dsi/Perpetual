# %% [markdown]
# #### In this jupyter notebook, I use k-mean to cluster Galveston's parcels to 60 clusters. The "Galv_Parcel_Complete.geojson" I used is created by Ziyu

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import csv
import geopandas as gpd

# %%
# Read the dataset that contains categories coded by Ziyu
zone = gpd.read_file("../data/Galv_Parcel_Complete.geojson").to_crs(epsg=4326)
zone.head(5)
# Out:
#    OBJECTID_l      ID               GEOID              NAME ADDRESS  \
# 0           1  436684  5912-4000-0001-000  CRVI HPW TRS INC    None
# 1           2  432154  0121-0001-0010-000  CRVI HPW TRS INC    None
# 2           3  436685  5912-4000-0002-000  CRVI HPW TRS INC    None
# 3           4  436686  5912-4000-0003-000  CRVI HPW TRS INC    None
# 4           5  729563  5912-4000-0000-007  CRVI HPW TRS INC    None
#
#                        ADDRESS2 ADDRESS3    CITY  ST    ZIP  ...  \
# 0  1601 S MOPAC EXPWY STE D-175     None  AUSTIN  TX  78746  ...
# 1  1601 S MOPAC EXPWY STE D-175     None  AUSTIN  TX  78746  ...
# 2  1601 S MOPAC EXPWY STE D-175     None  AUSTIN  TX  78746  ...
# 3  1601 S MOPAC EXPWY STE D-175     None  AUSTIN  TX  78746  ...
# 4  1601 S MOPAC EXPWY STE D-175     None  AUSTIN  TX  78746  ...
#
#      Shape_Leng    Shape_Area index_righ OBJECTID_r             Name_1 Code  \
# 0   1427.244952  6.686772e+04         29         30  CITY OF GALVESTON  C30
# 1  10675.442458  3.743268e+06         29         30  CITY OF GALVESTON  C30
# 2    767.678590  3.335669e+04         29         30  CITY OF GALVESTON  C30
# 3    921.451609  4.332103e+04         29         30  CITY OF GALVESTON  C30
# 4   4161.981292  1.838646e+05         29         30  CITY OF GALVESTON  C30
#
#       Shape_Le_1    Shape_Ar_1    Coded_LANDUSE  \
# 0  186359.261489  2.612547e+08       Commercial
# 1  186359.261489  2.612547e+08  Not of Interest
# 2  186359.261489  2.612547e+08       Commercial
# 3  186359.261489  2.612547e+08       Commercial
# 4  186359.261489  2.612547e+08  Not of Interest
#
#                                             geometry
# 0  POLYGON ((-95.11211 29.09321, -95.11205 29.093...
# 1  POLYGON ((-95.11336 29.09335, -95.11323 29.093...
# 2  POLYGON ((-95.11151 29.09375, -95.11166 29.093...
# 3  POLYGON ((-95.11156 29.09466, -95.11156 29.094...
# 4  POLYGON ((-95.11162 29.09478, -95.11161 29.094...
#
# [5 rows x 35 columns]

# %%
# Select the columns I focus
zone = zone[["GEOID","NAME","Shape_Area","geometry","Coded_LANDUSE"]]
zone
# Out:
#                     GEOID                       NAME    Shape_Area  \
# 0      5912-4000-0001-000           CRVI HPW TRS INC  6.686772e+04
# 1      0121-0001-0010-000           CRVI HPW TRS INC  3.743268e+06
# 2      5912-4000-0002-000           CRVI HPW TRS INC  3.335669e+04
# 3      5912-4000-0003-000           CRVI HPW TRS INC  4.332103e+04
# 4      5912-4000-0000-007           CRVI HPW TRS INC  1.838646e+05
# ...                   ...                        ...           ...
# 28182  0190-0002-0000-000  PORT OF HOUSTON AUTHORITY  7.723167e+06
# 28183  0190-0001-0000-000          USA-US GOVERNMENT  2.590386e+07
# 28184  0190-0038-0000-000          USA-US COASTGUARD  5.319753e+07
# 28185  0190-0041-0000-000             CITY-GALVESTON  8.999457e+06
# 28186  0190-0039-0000-000          USA-US COASTGUARD  5.319408e+06
#
#                                                 geometry    Coded_LANDUSE
# 0      POLYGON ((-95.11211 29.09321, -95.11205 29.093...       Commercial
# 1      POLYGON ((-95.11336 29.09335, -95.11323 29.093...  Not of Interest
# 2      POLYGON ((-95.11151 29.09375, -95.11166 29.093...       Commercial
# 3      POLYGON ((-95.11156 29.09466, -95.11156 29.094...       Commercial
# 4      POLYGON ((-95.11162 29.09478, -95.11161 29.094...  Not of Interest
# ...                                                  ...              ...
# 28182  POLYGON ((-94.77938 29.34105, -94.78123 29.335...  Not of Interest
# 28183  POLYGON ((-94.78022 29.34146, -94.78231 29.335...       Industrial
# 28184  POLYGON ((-94.80645 29.35329, -94.80550 29.352...       Industrial
# 28185  POLYGON ((-94.79534 29.34979, -94.79581 29.349...       Industrial
# 28186  POLYGON ((-94.82012 29.35434, -94.81951 29.354...       Industrial
#
# [28187 rows x 5 columns]

# %%
# Calculate centroid and area of each column and make them columns
zone["Centroid"] = zone.centroid
zone["Area"] = zone.area
zone.head(5)
# Out:
# C:\Users\Charlie Qiu\AppData\Local\Temp\ipykernel_60108\2613634853.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zone["Centroid"] = zone.centroid
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\Charlie Qiu\AppData\Local\Temp\ipykernel_60108\2613634853.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zone["Area"] = zone.area
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                 GEOID              NAME    Shape_Area  \
# 0  5912-4000-0001-000  CRVI HPW TRS INC  6.686772e+04
# 1  0121-0001-0010-000  CRVI HPW TRS INC  3.743268e+06
# 2  5912-4000-0002-000  CRVI HPW TRS INC  3.335669e+04
# 3  5912-4000-0003-000  CRVI HPW TRS INC  4.332103e+04
# 4  5912-4000-0000-007  CRVI HPW TRS INC  1.838646e+05
#
#                                             geometry    Coded_LANDUSE  \
# 0  POLYGON ((-95.11211 29.09321, -95.11205 29.093...       Commercial
# 1  POLYGON ((-95.11336 29.09335, -95.11323 29.093...  Not of Interest
# 2  POLYGON ((-95.11151 29.09375, -95.11166 29.093...       Commercial
# 3  POLYGON ((-95.11156 29.09466, -95.11156 29.094...       Commercial
# 4  POLYGON ((-95.11162 29.09478, -95.11161 29.094...  Not of Interest
#
#                      Centroid          Area
# 0  POINT (-95.11232 29.09286)  5.761574e-07
# 1  POINT (-95.11815 29.08955)  3.223678e-05
# 2  POINT (-95.11182 29.09346)  2.872953e-07
# 3  POINT (-95.11179 29.09430)  3.732208e-07
# 4  POINT (-95.11220 29.09358)  1.583564e-06

# %%
# Used the weight dictionary we design before to assign category_weight for each row
# Feel free to change the weight here to have a different weighted version of collection point clustering
weight_dictionary = {"Commercial": 3, "Condo":2, "Residential Lot":2, "Residential Acreage":2, "Townhome":1.5, "Industrial":0.5, "Not of Interest": 0.1}
zone["category_weight"] = zone["Coded_LANDUSE"].map(weight_dictionary)
zone.head(5)
# Out:
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                 GEOID              NAME    Shape_Area  \
# 0  5912-4000-0001-000  CRVI HPW TRS INC  6.686772e+04
# 1  0121-0001-0010-000  CRVI HPW TRS INC  3.743268e+06
# 2  5912-4000-0002-000  CRVI HPW TRS INC  3.335669e+04
# 3  5912-4000-0003-000  CRVI HPW TRS INC  4.332103e+04
# 4  5912-4000-0000-007  CRVI HPW TRS INC  1.838646e+05
#
#                                             geometry    Coded_LANDUSE  \
# 0  POLYGON ((-95.11211 29.09321, -95.11205 29.093...       Commercial
# 1  POLYGON ((-95.11336 29.09335, -95.11323 29.093...  Not of Interest
# 2  POLYGON ((-95.11151 29.09375, -95.11166 29.093...       Commercial
# 3  POLYGON ((-95.11156 29.09466, -95.11156 29.094...       Commercial
# 4  POLYGON ((-95.11162 29.09478, -95.11161 29.094...  Not of Interest
#
#                      Centroid          Area  category_weight
# 0  POINT (-95.11232 29.09286)  5.761574e-07              3.0
# 1  POINT (-95.11815 29.08955)  3.223678e-05              0.1
# 2  POINT (-95.11182 29.09346)  2.872953e-07              3.0
# 3  POINT (-95.11179 29.09430)  3.732208e-07              3.0
# 4  POINT (-95.11220 29.09358)  1.583564e-06              0.1

# %%
# Calculate the weight of each point using this formula : area * category_weight (assigned in the above cell) and make new weight column
zone["weight"] = zone["Area"] * zone["category_weight"]
zone["Lat"] = zone["Centroid"].y
zone["Long"] = zone["Centroid"].x
zone.head(5)
# Out:
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                 GEOID              NAME    Shape_Area  \
# 0  5912-4000-0001-000  CRVI HPW TRS INC  6.686772e+04
# 1  0121-0001-0010-000  CRVI HPW TRS INC  3.743268e+06
# 2  5912-4000-0002-000  CRVI HPW TRS INC  3.335669e+04
# 3  5912-4000-0003-000  CRVI HPW TRS INC  4.332103e+04
# 4  5912-4000-0000-007  CRVI HPW TRS INC  1.838646e+05
#
#                                             geometry    Coded_LANDUSE  \
# 0  POLYGON ((-95.11211 29.09321, -95.11205 29.093...       Commercial
# 1  POLYGON ((-95.11336 29.09335, -95.11323 29.093...  Not of Interest
# 2  POLYGON ((-95.11151 29.09375, -95.11166 29.093...       Commercial
# 3  POLYGON ((-95.11156 29.09466, -95.11156 29.094...       Commercial
# 4  POLYGON ((-95.11162 29.09478, -95.11161 29.094...  Not of Interest
#
#                      Centroid          Area  category_weight        weight  \
# 0  POINT (-95.11232 29.09286)  5.761574e-07              3.0  1.728472e-06
# 1  POINT (-95.11815 29.08955)  3.223678e-05              0.1  3.223678e-06
# 2  POINT (-95.11182 29.09346)  2.872953e-07              3.0  8.618860e-07
# 3  POINT (-95.11179 29.09430)  3.732208e-07              3.0  1.119662e-06
# 4  POINT (-95.11220 29.09358)  1.583564e-06              0.1  1.583564e-07
#
#          Lat       Long
# 0  29.092858 -95.112316
# 1  29.089551 -95.118148
# 2  29.093462 -95.111815
# 3  29.094299 -95.111791
# 4  29.093582 -95.112204

# %%
# Draw an elbow plot to find best k
K_clusters = range(1,100)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = zone[['Lat']]
X_axis = zone[['Long']]
score = [kmeans[i].fit(Y_axis, X_axis).score(Y_axis, X_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %% [markdown]
# Any clusters large than ~10 have good score, so using clusters > 10 is rine

# %%
# Perform weighted k means with 60 clusters (weight is the "weight" column)
kmeans = KMeans(n_clusters = 60, init ='k-means++')
kmeans.fit(zone[["Lat","Long"]], sample_weight = zone["weight"]) # Compute k-means clustering.
zone['cluster_label'] = kmeans.fit_predict(zone[["Lat","Long"]], sample_weight = zone["weight"])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(zone[["Lat","Long"]], sample_weight = zone["weight"]) # Labels of each point
zone.head(10)
# Out:
# d:\python\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                 GEOID                                            NAME  \
# 0  5912-4000-0001-000                                CRVI HPW TRS INC
# 1  0121-0001-0010-000                                CRVI HPW TRS INC
# 2  5912-4000-0002-000                                CRVI HPW TRS INC
# 3  5912-4000-0003-000                                CRVI HPW TRS INC
# 4  5912-4000-0000-007                                CRVI HPW TRS INC
# 5  5912-4000-0000-003  PROPERTY OWNERS ASSOCIATION OF POINTE WEST INC
# 6  5912-2000-0000-006  PROPERTY OWNERS ASSOCIATION OF POINTE WEST INC
# 7  5912-2001-0001-000                                 HELLAIL INC LLC
# 8  5912-2001-0002-000                                     RASH KYLE L
# 9  5912-2001-0003-000                              WHITE KURT & VICKI
#
#      Shape_Area                                           geometry  \
# 0  6.686772e+04  POLYGON ((-95.11211 29.09321, -95.11205 29.093...
# 1  3.743268e+06  POLYGON ((-95.11336 29.09335, -95.11323 29.093...
# 2  3.335669e+04  POLYGON ((-95.11151 29.09375, -95.11166 29.093...
# 3  4.332103e+04  POLYGON ((-95.11156 29.09466, -95.11156 29.094...
# 4  1.838646e+05  POLYGON ((-95.11162 29.09478, -95.11161 29.094...
# 5  1.468714e+05  POLYGON ((-95.10903 29.09508, -95.10902 29.095...
# 6  1.871317e+03  POLYGON ((-95.10883 29.09511, -95.10881 29.095...
# 7  3.999991e+03  POLYGON ((-95.10874 29.09556, -95.10886 29.095...
# 8  4.000009e+03  POLYGON ((-95.10863 29.09565, -95.10874 29.095...
# 9  3.999043e+03  POLYGON ((-95.10851 29.09575, -95.10863 29.095...
#
#      Coded_LANDUSE                    Centroid          Area  category_weight  \
# 0       Commercial  POINT (-95.11232 29.09286)  5.761574e-07              3.0
# 1  Not of Interest  POINT (-95.11815 29.08955)  3.223678e-05              0.1
# 2       Commercial  POINT (-95.11182 29.09346)  2.872953e-07              3.0
# 3       Commercial  POINT (-95.11179 29.09430)  3.732208e-07              3.0
# 4  Not of Interest  POINT (-95.11220 29.09358)  1.583564e-06              0.1
# 5            Condo  POINT (-95.11035 29.09432)  1.265828e-06              2.0
# 6  Not of Interest  POINT (-95.10876 29.09493)  1.609684e-08              0.1
# 7  Residential Lot  POINT (-95.10888 29.09560)  3.444957e-08              2.0
# 8  Residential Lot  POINT (-95.10877 29.09569)  3.444976e-08              2.0
# 9  Residential Lot  POINT (-95.10865 29.09578)  3.443038e-08              2.0
#
#          weight        Lat       Long  cluster_label
# 0  1.728472e-06  29.092858 -95.112316             34
# 1  3.223678e-06  29.089551 -95.118148             34
# 2  8.618860e-07  29.093462 -95.111815             34
# 3  1.119662e-06  29.094299 -95.111791             34
# 4  1.583564e-07  29.093582 -95.112204             34
# 5  2.531657e-06  29.094320 -95.110354             34
# 6  1.609684e-09  29.094933 -95.108757             34
# 7  6.889913e-08  29.095596 -95.108884             34
# 8  6.889951e-08  29.095689 -95.108769             34
# 9  6.886075e-08  29.095781 -95.108653             34

# %%
# Create geodataframe for each polygon's centroid
zone_gdf = gpd.GeoDataFrame(
    zone, geometry=gpd.points_from_xy(zone.Long, zone.Lat, crs='epsg:4326'),crs=4326) 
zone_gdf["polygon"] = zone["geometry"]
zone_gdf.head(5)
# Out:
#                 GEOID              NAME    Shape_Area  \
# 0  5912-4000-0001-000  CRVI HPW TRS INC  6.686772e+04
# 1  0121-0001-0010-000  CRVI HPW TRS INC  3.743268e+06
# 2  5912-4000-0002-000  CRVI HPW TRS INC  3.335669e+04
# 3  5912-4000-0003-000  CRVI HPW TRS INC  4.332103e+04
# 4  5912-4000-0000-007  CRVI HPW TRS INC  1.838646e+05
#
#                      geometry    Coded_LANDUSE                    Centroid  \
# 0  POINT (-95.11232 29.09286)       Commercial  POINT (-95.11232 29.09286)
# 1  POINT (-95.11815 29.08955)  Not of Interest  POINT (-95.11815 29.08955)
# 2  POINT (-95.11182 29.09346)       Commercial  POINT (-95.11182 29.09346)
# 3  POINT (-95.11179 29.09430)       Commercial  POINT (-95.11179 29.09430)
# 4  POINT (-95.11220 29.09358)  Not of Interest  POINT (-95.11220 29.09358)
#
#            Area  category_weight        weight        Lat       Long  \
# 0  5.761574e-07              3.0  1.728472e-06  29.092858 -95.112316
# 1  3.223678e-05              0.1  3.223678e-06  29.089551 -95.118148
# 2  2.872953e-07              3.0  8.618860e-07  29.093462 -95.111815
# 3  3.732208e-07              3.0  1.119662e-06  29.094299 -95.111791
# 4  1.583564e-06              0.1  1.583564e-07  29.093582 -95.112204
#
#    cluster_label                     polygon
# 0             34  POINT (-95.11232 29.09286)
# 1             34  POINT (-95.11815 29.08955)
# 2             34  POINT (-95.11182 29.09346)
# 3             34  POINT (-95.11179 29.09430)
# 4             34  POINT (-95.11220 29.09358)

# %%
# Create geodataframe for each cluster center
center_df = pd.DataFrame(centers, columns = ['lat','long'])
center_gdf = gpd.GeoDataFrame(
    center_df, geometry=gpd.points_from_xy(center_df.long, center_df.lat, crs='epsg:4326'),crs=4326) 
center_gdf.head(5)
# Out:
#          lat       long                    geometry
# 0  29.201904 -94.944011  POINT (-94.94401 29.20190)
# 1  29.298048 -94.819682  POINT (-94.81968 29.29805)
# 2  29.131075 -95.061183  POINT (-95.06118 29.13107)
# 3  29.264259 -94.877844  POINT (-94.87784 29.26426)
# 4  29.339165 -94.790654  POINT (-94.79065 29.33916)

# %%
# Create buffer zone as the coverage area (In Galveston, 0.004° = 1/4 mile = 5-min walking distance)
# Create geodataframe for each coverage area
buffer = center_gdf.buffer(0.004)
center_df_1 = pd.DataFrame(centers, columns = ['lat','long'])
center_gdf_1 = gpd.GeoDataFrame(
    center_df_1, geometry=buffer,crs=4326) 
center_gdf_1
# Out:
# C:\Users\Charlie Qiu\AppData\Local\Temp\ipykernel_60108\1240696157.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   buffer = center_gdf.buffer(0.004)
#           lat       long                                           geometry
# 0   29.201904 -94.944011  POLYGON ((-94.94001 29.20190, -94.94003 29.201...
# 1   29.298048 -94.819682  POLYGON ((-94.81568 29.29805, -94.81570 29.297...
# 2   29.131075 -95.061183  POLYGON ((-95.05718 29.13107, -95.05720 29.130...
# 3   29.264259 -94.877844  POLYGON ((-94.87384 29.26426, -94.87386 29.263...
# 4   29.339165 -94.790654  POLYGON ((-94.78665 29.33916, -94.78667 29.338...
# 5   29.264176 -94.840561  POLYGON ((-94.83656 29.26418, -94.83658 29.263...
# 6   29.245908 -94.917369  POLYGON ((-94.91337 29.24591, -94.91339 29.245...
# 7   29.170826 -95.001971  POLYGON ((-94.99797 29.17083, -94.99799 29.170...
# 8   29.106732 -95.096759  POLYGON ((-95.09276 29.10673, -95.09278 29.106...
# 9   29.287440 -94.801409  POLYGON ((-94.79741 29.28744, -94.79743 29.287...
# 10  29.332274 -94.736772  POLYGON ((-94.73277 29.33227, -94.73279 29.331...
# 11  29.233650 -94.891720  POLYGON ((-94.88772 29.23365, -94.88774 29.233...
# 12  29.312660 -94.769572  POLYGON ((-94.76557 29.31266, -94.76559 29.312...
# 13  29.279759 -94.828787  POLYGON ((-94.82479 29.27976, -94.82481 29.279...
# 14  29.228554 -94.922662  POLYGON ((-94.91866 29.22855, -94.91868 29.228...
# 15  29.304436 -94.791288  POLYGON ((-94.78729 29.30444, -94.78731 29.304...
# 16  29.153089 -95.030006  POLYGON ((-95.02601 29.15309, -95.02603 29.152...
# 17  29.285201 -94.868839  POLYGON ((-94.86484 29.28520, -94.86486 29.284...
# 18  29.246775 -94.871383  POLYGON ((-94.86738 29.24678, -94.86740 29.246...
# 19  29.145756 -95.038735  POLYGON ((-95.03474 29.14576, -95.03475 29.145...
# 20  29.268382 -94.858152  POLYGON ((-94.85415 29.26838, -94.85417 29.267...
# 21  29.287431 -94.821090  POLYGON ((-94.81709 29.28743, -94.81711 29.287...
# 22  29.326497 -94.770963  POLYGON ((-94.76696 29.32650, -94.76698 29.326...
# 23  29.225714 -94.940945  POLYGON ((-94.93694 29.22571, -94.93696 29.225...
# 24  29.298847 -94.782868  POLYGON ((-94.77887 29.29885, -94.77889 29.298...
# 25  29.125202 -95.070999  POLYGON ((-95.06700 29.12520, -95.06702 29.124...
# 26  29.181627 -94.982618  POLYGON ((-94.97862 29.18163, -94.97864 29.181...
# 27  29.302161 -94.802271  POLYGON ((-94.79827 29.30216, -94.79829 29.301...
# 28  29.276607 -94.816672  POLYGON ((-94.81267 29.27661, -94.81269 29.276...
# 29  29.216310 -94.932354  POLYGON ((-94.92835 29.21631, -94.92837 29.215...
# 30  29.293601 -94.830978  POLYGON ((-94.82698 29.29360, -94.82700 29.293...
# 31  29.257354 -94.896649  POLYGON ((-94.89265 29.25735, -94.89267 29.256...
# 32  29.224796 -94.906773  POLYGON ((-94.90277 29.22480, -94.90279 29.224...
# 33  29.289993 -94.857185  POLYGON ((-94.85318 29.28999, -94.85320 29.289...
# 34  29.095100 -95.108745  POLYGON ((-95.10474 29.09510, -95.10476 29.094...
# 35  29.141136 -95.045948  POLYGON ((-95.04195 29.14114, -95.04197 29.140...
# 36  29.272848 -94.823873  POLYGON ((-94.81987 29.27285, -94.81989 29.272...
# 37  29.241487 -94.881977  POLYGON ((-94.87798 29.24149, -94.87800 29.241...
# 38  29.237946 -94.904602  POLYGON ((-94.90060 29.23795, -94.90062 29.237...
# 39  29.320108 -94.795390  POLYGON ((-94.79139 29.32011, -94.79141 29.319...
# 40  29.201156 -94.965332  POLYGON ((-94.96133 29.20116, -94.96135 29.200...
# 41  29.321137 -94.813297  POLYGON ((-94.80930 29.32114, -94.80932 29.320...
# 42  29.207339 -94.934351  POLYGON ((-94.93035 29.20734, -94.93037 29.206...
# 43  29.215773 -94.918006  POLYGON ((-94.91401 29.21577, -94.91403 29.215...
# 44  29.174613 -94.993738  POLYGON ((-94.98974 29.17461, -94.98976 29.174...
# 45  29.292930 -94.810792  POLYGON ((-94.80679 29.29293, -94.80681 29.292...
# 46  29.341015 -94.810515  POLYGON ((-94.80652 29.34102, -94.80653 29.340...
# 47  29.268775 -94.831711  POLYGON ((-94.82771 29.26878, -94.82773 29.268...
# 48  29.114952 -95.087347  POLYGON ((-95.08335 29.11495, -95.08337 29.114...
# 49  29.290873 -94.840267  POLYGON ((-94.83627 29.29087, -94.83629 29.290...
# 50  29.135951 -95.055539  POLYGON ((-95.05154 29.13595, -95.05156 29.135...
# 51  29.274750 -94.840045  POLYGON ((-94.83604 29.27475, -94.83606 29.274...
# 52  29.292860 -94.792756  POLYGON ((-94.78876 29.29286, -94.78878 29.292...
# 53  29.323648 -94.749938  POLYGON ((-94.74594 29.32365, -94.74596 29.323...
# 54  29.308849 -94.778737  POLYGON ((-94.77474 29.30885, -94.77476 29.308...
# 55  29.282033 -94.809318  POLYGON ((-94.80532 29.28203, -94.80534 29.281...
# 56  29.207109 -94.950757  POLYGON ((-94.94676 29.20711, -94.94678 29.206...
# 57  29.257403 -94.850385  POLYGON ((-94.84638 29.25740, -94.84640 29.257...
# 58  29.257778 -94.869862  POLYGON ((-94.86586 29.25778, -94.86588 29.257...
# 59  29.163103 -95.014353  POLYGON ((-95.01035 29.16310, -95.01037 29.162...

# %%
# Create the geojson for parcel with weights. This shapefile is equal to the 
# galveston_parcel_skater.shp in the galveston_parcel_skater folder under the
# Skater_Clustering algorithm. I used this shapefile for skater clustering
polygon = gpd.read_file("Galv_Parcel_Complete.geojson").to_crs(epsg=4326)
zone_gdf_copy = zone_gdf[:]
zone_gdf_copy = zone_gdf_copy.iloc[:,[0,1,2,4,6,7,8,9,10,11]]
zone_gdf_copy = gpd.GeoDataFrame(zone_gdf_copy, geometry = polygon.geometry)
zone_gdf_copy.to_file("Galveston_parcel_polygon.geojson", driver="GeoJSON")

# %%
# Create the geojson for parcel centriod
zone_gdf[["geometry","cluster_label","Coded_LANDUSE","Lat","Long"]].to_file("galveston_parcel_centroid_60.geojson", driver="GeoJSON")

# %%
# Create the geojson for cluster center (collection point)'s buffer zone (coverage area)
center_gdf_1.to_file("galveston_parcel_cluster_buffer_60.geojson", driver="GeoJSON")

# %%
# Create the geojson for cluster center (collection point)
center_gdf.to_file("galveston_parcel_cluster_center_60.geojson", driver="GeoJSON")

# %% [markdown]
# #### Please use Calculating_Distance_Clct_Galveston_60 for further operation
# ####  I use QGIS and ArcGIS to finish mapping, the links are in the README.md
